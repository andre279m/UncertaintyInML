# %% [markdown]
# # Imports

# %%
import rdflib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# # Files

# %%
# Files
protein_file_path = 'DB/9606.protein.enrichment.terms.v12.0.txt'
protein_full_links_file_path = 'DB/9606.protein.links.detailed.v12.0.txt'

prots = pd.read_csv(protein_file_path, sep='\t', header=0)
prots = prots[prots['term'].str.startswith('GO:')].reset_index(drop=True)

# %%
protein_id_counts = prots['#string_protein_id'].value_counts()
print(protein_id_counts.mean())
# Out:
# 183.74210637847003

# %%
huri_pairs = pd.read_csv('DB/HuriTest/HuRI.tsv', sep = '\t',header=None,names=['protein1', 'protein2'])
mappings = pd.read_csv('DB/HuriTest/idmapping_2024_03_15.tsv',sep='\t', header=0)
annotations_file_path = pd.read_csv('DB/HuriTest/goa_human.gaf',sep='\t', header=None)

# %%
mappings_dict = {}

for index, row in mappings.iterrows():
    from_value = row['From']
    entry_value = row['Entry']
    
    if from_value in mappings_dict:
        mappings_dict[from_value].append(entry_value)
    else:
        mappings_dict[from_value] = [entry_value]
        
mappings_dict
# Out:
# {'ENSG00000277075': ['P04908'],
#  'ENSG00000181786': ['Q8TC94'],
#  'ENSG00000137404': ['Q8IXM6', 'H0Y6T6'],
#  'ENSG00000197471': ['P16150', 'C9JUK7'],
#  'ENSG00000206203': ['Q96PF2'],
#  'ENSG00000117625': ['Q9P2K3',
#   'B4DV59',
#   'E9PPC5',
#   'E9PQE5',
#   'E9PR63',
#   'H0YDD7',
#   'H0YDR8',
#   'H0YF22'],
#  'ENSG00000113595': ['P36406', 'D6R9E9', 'D6RBN4', 'D6RD22'],
#  'ENSG00000198546': ['Q8NB15'],
#  'ENSG00000196632': ['Q9BYP7', 'B1AQN8'],
#  'ENSG00000142583': ['P22732', 'K7EIT1', 'K7EJR1', 'K7EJZ0', 'K7EQI3'],
#  'ENSG00000167768': ['P04264'],
#  'ENSG00000138813': ['Q53FE4', 'D6RHU4'],
#  'ENSG00000139192': ['Q9BX59', 'G3V1T3'],
#  'ENSG00000171680': ['O94827',
#   'A0A5F9ZHW8',
#   'A0A6Q8PF22',
#   'A0A6Q8PG76',
#   'A0A6Q8PGZ5',
#   'A0A6Q8PHD3',
#   'A0A6Q8PHJ1',
#   'A0A6Q8PHR5',
#   'A0A6Q8PHS0',
#   'A0A7I2PMD6',
#   'A0A804EMX3',
#   'Q5SY18'],
#  'ENSG00000256061': ['Q8WXU2', 'B4DY92', 'E5RJ13'],
#  'ENSG00000120437': ['Q9BWD1'],
#  'ENSG00000068079': ['P80217'],
#  'ENSG00000125170': ['Q8TEW6',
#   'A0A1B0GX86',
#   'H3BN90',
#   'H3BPY9',
#   'H3BQ19',
#   'H3BS85',
#   'H3BSK0',
#   'H3BST9',
#   'H3BTI4',
#   'H3BTI7',
#   'H3BTK2',
#   'H3BV67',
#   'H3BVB4'],
#  'ENSG00000172867': ['P35908'],
#  'ENSG00000150244': ['Q8IWZ4'],
#  'ENSG00000163071': ['Q8TC71', 'D6RGI2', 'E7EVV3'],
#  'ENSG00000103024': ['Q13232', 'H3BMQ7', 'H3BPD9', 'H3BPR2', 'H3BRA8'],
#  'ENSG00000221838': ['O00189',
#   'C9IZL5',
#   'C9JC87',
#   'C9JMG3',
#   'C9JWL4',
#   'F8WCC5',
#   'F8WCR6',
#   'F8WDR3',
#   'H0Y6K1',
#   'H7BZV3',
#   'H7C0A0'],
#  'ENSG00000163938': ['Q9BVP2', 'B4DMU5', 'C9JYH9', 'C9JZT7'],
#  'ENSG00000178409': ['Q5T5X7'],
#  'ENSG00000152503': ['Q9NQ86', 'D6RAU9', 'E9PBG3'],
#  'ENSG00000180549': ['Q11130'],
#  'ENSG00000125124': ['Q9BXC9',
#   'A0A804F8L3',
#   'A0A804HHV5',
#   'A0A804HI33',
#   'A0A804HIE0',
#   'A0A804HIE1',
#   'A0A804HIK5',
#   'A0A804HIQ9',
#   'A0A804HIZ8',
#   'A0A804HJ30',
#   'A0A804HJQ5',
#   'A0A804HJV0',
#   'A0A804HJV2',
#   'A0A804HK25',
#   'A0A804HK50',
#   'A0A804HK51',
#   'A0A804HK97',
#   'A0A804HKF2',
#   'A0A804HKG1',
#   'A0A804HKI7',
#   'A0A804HKL9',
#   'A0A804HLC6',
#   'A0A804HLD7',
#   'A0A804HLF5',
#   'A0A804HLL2',
#   'H3BNS7',
#   'H3BQ79',
#   'H3BRL0'],
#  'ENSG00000159674': ['Q9BUD6',
#   'A0A1Y8ELY7',
#   'D6RA41',
#   'D6RB12',
#   'D6RBY3',
#   'D6REX2',
#   'D6RFY9',
#   'D6RIH5'],
#  'ENSG00000161249': ['Q6E0U4',
#   'A3EZ84',
#   'C9IYI1',
#   'C9J186',
#   'C9J3V3',
#   'C9JCN1',
#   'E7EMS7',
#   'E9PAQ7',
#   'H7BZ95',
#   'M0QZU6',
#   'M0R0A5',
#   'M0R0W2',
#   'M0R1M0',
#   'M0R265',
#   'M0R3F8',
#   'R4GMQ0',
#   'S4R2X7',
#   'S4R3L7',
#   'S4R427'],
#  'ENSG00000168000': ['Q96G97',
#   'A0A804HHX0',
#   'A0A804HIE2',
#   'A0A804HIJ7',
#   'A0A804HJB1',
#   'A0A804HJW1',
#   'A0A804HK11',
#   'A0A804HK83',
#   'A0A804HKZ9',
#   'E9PIU3',
#   'E9PJK0',
#   'E9PJS9',
#   'E9PPN5',
#   'E9PR78',
#   'E9PRU2',
#   'E9PSB5',
#   'F8W7Q8',
#   'F8WER0',
#   'H7BXM1',
#   'H7BYY0',
#   'H7C2D5',
#   'J3KQ12'],
#  'ENSG00000104518': ['P57764',
#   'E9PIB2',
#   'E9PNZ0',
#   'E9PQ48',
#   'E9PQR9',
#   'E9PRF1',
#   'G3V1A6',
#   'H0YDB0'],
#  'ENSG00000009307': ['O75534',
#   'A0A1Y8EMC9',
#   'A0A8I5KNL1',
#   'A0A8I5KPC0',
#   'A0A8I5KPJ6',
#   'A0A8I5KPQ8',
#   'A0A8I5KS07',
#   'A0A8I5KTQ3',
#   'A0A8I5KV85',
#   'A0A8I5KW29',
#   'A0A8I5KW72',
#   'A0A8I5KWW0',
#   'A0A8I5KXH5',
#   'A0A8I5KXL1',
#   'A0A8I5KYL4',
#   'A0A8I5KYL8',
#   'A0A8I5KYY8',
#   'A0A8I5QJA6',
#   'A0A8I5QKX0',
#   'E9PJK7',
#   'E9PKN4',
#   'E9PLD4',
#   'E9PLT0',
#   'E9PNG3'],
#  'ENSG00000147378': ['Q969F0', 'H7C1I5'],
#  'ENSG00000198498': ['Q96EY4', 'D6RA57', 'D6RC31', 'D6RE67', 'H0Y9X1'],
#  'ENSG00000028528': ['Q13596',
#   'H0YK42',
#   'H0YK43',
#   'H0YK58',
#   'H0YKD5',
#   'H0YKL5',
#   'H0YKT3',
#   'J3KPH4'],
#  'ENSG00000169122': ['Q8TC76'],
#  'ENSG00000134516': ['Q92608',
#   'A0A3B3IRS9',
#   'A0A3B3ISB1',
#   'A0A8Q3WL64',
#   'E5RFJ0',
#   'H0YB76'],
#  'ENSG00000188375': ['Q6NXT2'],
#  'ENSG00000179912': ['Q9Y2K5',
#   'A0A0U1RRA6',
#   'B5MCG9',
#   'B5MCU0',
#   'C9J7N6',
#   'H0YIX9',
#   'H7C0E9'],
#  'ENSG00000072110': ['P12814',
#   'A0A7I2V4Y4',
#   'A0A804HII9',
#   'A0A804HIN7',
#   'A0A804HIY0',
#   'A0A804HJN7',
#   'A0A804HJQ9',
#   'A0A804HJU8',
#   'A0A804HK61',
#   'A0A804HKE2',
#   'A0A804HL31',
#   'A0A804HLD0',
#   'A0A804HLF4',
#   'G3V2E8',
#   'G3V2N5',
#   'G3V2W4',
#   'G3V2X9',
#   'G3V380',
#   'G3V5M4',
#   'H0YJ11',
#   'H0YJW3',
#   'H7C5W8',
#   'H9KV75'],
#  'ENSG00000161677': ['Q8TAC2', 'M0QZL8'],
#  'ENSG00000266094': ['Q8WWW0', 'A0A075B763', 'A0A1B0GTG4', 'Q8TEK8'],
#  'ENSG00000165672': ['P30048'],
#  'ENSG00000213619': ['O75489', 'E9PJE7', 'E9PKL8', 'E9PS48', 'G3V194'],
#  'ENSG00000095485': ['Q69YN2', 'A0A0S2Z5Q6', 'A0A286YEP9', 'A0A286YF56'],
#  'ENSG00000167470': ['Q504T8', 'A0A804HKJ8'],
#  'ENSG00000196224': ['Q6L8H2'],
#  'ENSG00000127314': ['P61224',
#   'B7ZB78',
#   'E7ESV4',
#   'F5GWU8',
#   'F5GX62',
#   'F5GYB5',
#   'F5GYH7',
#   'F5GZG1',
#   'F5H004',
#   'F5H077',
#   'F5H0B7',
#   'F5H0S2',
#   'F5H491',
#   'F5H4H0',
#   'F5H500',
#   'F5H6R7',
#   'F5H7Y6',
#   'F5H823',
#   'F8WBC0'],
#  'ENSG00000184497': ['Q8WV15', 'A0A0B4J2D1'],
#  'ENSG00000150045': ['Q9NZS2', 'Q4KMZ4', 'Q4KN05', 'Q4KN30'],
#  'ENSG00000166135': ['Q9NWT6', 'E9PL41', 'E9PNR8'],
#  'ENSG00000105146': ['Q9UQB9', 'B4DXA6', 'M0QX60', 'M0QYK8', 'Q5Y191'],
#  'ENSG00000187957': ['Q8NFT8'],
#  'ENSG00000270806': ['Q8WW18', 'A0A075B7C2', 'A0A075B7E2'],
#  'ENSG00000162399': ['Q8WZ55'],
#  'ENSG00000077279': ['O43602',
#   'A0A1B0GWD1',
#   'A0A7P0T9C5',
#   'A0A804CF28',
#   'A0A9L9PYE1',
#   'A0A9S7JGE9',
#   'A0A9S7N7F7',
#   'A8K340',
#   'E7EU50'],
#  'ENSG00000171960': ['O43447',
#   'A0A7I2V2H6',
#   'A0A7I2V343',
#   'A0A7I2V5V0',
#   'A0A7I2YQS4',
#   'C9JQD4',
#   'H0YEL5'],
#  'ENSG00000079805': ['P50570', 'K7EMQ3', 'K7EMR9', 'K7ENE7', 'K7EPK9'],
#  'ENSG00000145354': ['Q8N5K1', 'A0A2R8Y4Y3', 'A0A2R8Y540', 'D6RCF4', 'I3L1N9'],
#  'ENSG00000243317': ['E0CX11', 'A0A096LP97'],
#  'ENSG00000079393': ['Q9UII6',
#   'A0A9L9PXN7',
#   'A0A9L9PYL3',
#   'E9PSD4',
#   'U3KQA1',
#   'U3KQB7'],
#  'ENSG00000113391': ['Q8WUF8', 'B4DMI0', 'E9PBM2'],
#  'ENSG00000121900': ['Q969K7'],
#  'ENSG00000006831': ['Q86V24'],
#  'ENSG00000178386': ['Q9UK11', 'K7EPW2', 'K7EQ32', 'K7ER65'],
#  'ENSG00000270765': ['Q8NHY3'],
#  'ENSG00000107816': ['Q9BRK4', 'B1AL11', 'B1AL12', 'B1AL13', 'S4R3W7'],
#  'ENSG00000181035': ['Q86VD7'],
#  'ENSG00000033122': ['A0A075B6E9',
#   'A0A494C1A4',
#   'B1AKT2',
#   'F8WE45',
#   'K7ELH5',
#   'V9GY23',
#   'V9GYE1',
#   'V9GZ42'],
#  'ENSG00000054356': ['Q16849',
#   'A0A1B0GX26',
#   'C9J392',
#   'C9JCQ0',
#   'C9JJL7',
#   'C9JR27',
#   'H7C0U9',
#   'U3KQ66'],
#  'ENSG00000162598': ['Q8N0U7', 'C9JPP7'],
#  'ENSG00000162444': ['Q96R05', 'B1AQ60'],
#  'ENSG00000185924': ['Q86UN2'],
#  'ENSG00000186049': ['Q86Y46', 'H0YIC5'],
#  'ENSG00000265808': ['O75396', 'A0A087X1A9'],
#  'ENSG00000167487': ['Q53HC5', 'M0QXE1', 'M0R049', 'M0R1N0', 'M0R1P3'],
#  'ENSG00000134333': ['P00338',
#   'F5GWW2',
#   'F5GXC7',
#   'F5GXH2',
#   'F5GXU1',
#   'F5GXY2',
#   'F5GYU2',
#   'F5GZQ4',
#   'F5H5J4',
#   'F5H6W8',
#   'F5H8H6'],
#  'ENSG00000123219': ['Q9BS16',
#   'D6R984',
#   'D6RAX0',
#   'D6RBN6',
#   'D6RC76',
#   'D6RHD3',
#   'D6RJF0',
#   'H0Y9K8'],
#  'ENSG00000142273': ['Q9ULV8', 'A0A2R8Y647'],
#  'ENSG00000149256': ['Q6N022', 'E9PPG4', 'H0YCJ4', 'H0YCW4'],
#  'ENSG00000100532': ['Q99675',
#   'A0A7P0Z480',
#   'A0A7P0Z4Q1',
#   'G3V229',
#   'G3V2K9',
#   'G3V412',
#   'M0QZQ7'],
#  'ENSG00000167476': ['Q96MG2'],
#  'ENSG00000137074': ['Q7Z2E3',
#   'A0A0A0MRW7',
#   'A0A5F9ZGW5',
#   'A0A5F9ZI51',
#   'A0A5K1VW64',
#   'A0A5K1VW80',
#   'C9J8U3',
#   'F8WBD6',
#   'F8WBM3',
#   'Q6JV79'],
#  'ENSG00000266412': ['Q13772', 'B4DF87', 'B4DZ85'],
#  'ENSG00000090661': ['Q9HA82',
#   'H0YKC9',
#   'H0YKR4',
#   'H0YKS3',
#   'H0YLY3',
#   'H0YMY6',
#   'H0YN04',
#   'H0YNR6'],
#  'ENSG00000143816': ['O14904'],
#  'ENSG00000203784': ['Q5T871'],
#  'ENSG00000198934': ['Q9HCI5'],
#  'ENSG00000142599': ['Q9P2R6',
#   'A0A075B770',
#   'A0A590UJ84',
#   'A0A590UK57',
#   'A0A994J475',
#   'A0A994J792',
#   'B1AKN3',
#   'D6RA28',
#   'H0Y975',
#   'H7BYW9',
#   'K7EIE3',
#   'K7EIQ4',
#   'K7EJQ1'],
#  'ENSG00000138162': ['O95359',
#   'A0A0U1RRM9',
#   'D6RAA5',
#   'E7EMZ9',
#   'E9PBC6',
#   'E9PGB3',
#   'H0Y8P9',
#   'H0Y911',
#   'H0Y954',
#   'H0Y9C3',
#   'H0Y9Y7',
#   'H0YA73',
#   'Q4VXL4',
#   'Q4VXL8'],
#  'ENSG00000275714': ['P68431'],
#  'ENSG00000049449': ['Q15293', 'E9PLM2', 'H0YDA4', 'H0YER5'],
#  'ENSG00000074527': ['Q9HB63', 'A0A6I8PS14', 'F8W0I7'],
#  'ENSG00000144229': ['Q9C0I4', 'R4GMU2'],
#  'ENSG00000158714': ['Q9P0V8'],
#  'ENSG00000186462': ['Q9ULW6'],
#  'ENSG00000172465': ['Q15170'],
#  'ENSG00000131981': ['P17931', 'G3V3R6', 'G3V407'],
#  'ENSG00000064655': ['O00167', 'B1AKW3', 'E7ETN2'],
#  'ENSG00000155827': ['Q5VTR2', 'C9J0A5', 'C9JWJ4', 'C9JXC9'],
#  'ENSG00000125533': ['Q8NDY6', 'A0A087WXG3'],
#  'ENSG00000008130': ['O95544',
#   'A0A0A0MR98',
#   'J3KSP9',
#   'J3KTI3',
#   'J3QR86',
#   'J3QRC0'],
#  'ENSG00000158806': ['Q86SE8', 'E5RFQ8', 'E5RGN1'],
#  'ENSG00000162571': ['Q6ZVT0', 'A0A669K9N4', 'J3QRK8'],
#  'ENSG00000089775': ['P24278', 'G3V2K3', 'G3V351'],
#  'ENSG00000166086': ['Q9BX67', 'H0YCW9', 'H0YD98'],
#  'ENSG00000136003': ['Q9H1K1', 'B3KQ30', 'B4DNC9', 'F5H5N2', 'F5H672'],
#  'ENSG00000075391': ['Q9UJF2',
#   'A0A8Q3SIU1',
#   'A0A8Q3SIZ5',
#   'A0A8Q3SJF6',
#   'H0Y638'],
#  'ENSG00000167703': ['Q8N370', 'I3L3E3', 'I3L4J2', 'I3L4V3'],
#  'ENSG00000171703': ['Q15560', 'A0A0A0MT58', 'Q5JRI7', 'Q5JRI8', 'Q86VL0'],
#  'ENSG00000243335': ['Q96MP8',
#   'A0A1W2PP71',
#   'A0A1W2PQ65',
#   'A0A1W2PQB2',
#   'A0A1W2PQL2',
#   'A0A1W2PQM8',
#   'A0A1W2PR57',
#   'A0A1W2PS30',
#   'A0A1X7SBW1',
#   'C9JTB6'],
#  'ENSG00000106948': ['Q7Z591'],
#  'ENSG00000188293': ['Q6UW32'],
#  'ENSG00000135446': ['P11802',
#   'F8VTV8',
#   'F8VWX7',
#   'F8VXD2',
#   'F8VYH9',
#   'F8VYY1',
#   'F8VZ13',
#   'F8VZ51',
#   'F8VZZ0',
#   'F8W1L8',
#   'Q96BE9'],
#  'ENSG00000158769': ['Q9Y624', 'A0A087WY82'],
#  'ENSG00000170523': ['P78385'],
#  'ENSG00000182585': ['Q6UW88', 'A0PK19', 'H3BM13'],
#  'ENSG00000131080': ['Q9HAV5'],
#  'ENSG00000126337': ['O76013'],
#  'ENSG00000171916': ['Q6DKI2',
#   'J3KRF0',
#   'J3KSV0',
#   'J3KSY2',
#   'J3KT17',
#   'J3QKS2',
#   'J3QR96',
#   'J3QSH0'],
#  'ENSG00000111906': ['Q7Z4H3', 'V9GYS5', 'V9GZ04'],
#  'ENSG00000170037': ['Q8N137',
#   'I3L0P9',
#   'I3L1A6',
#   'I3L1B0',
#   'I3L1E9',
#   'I3L1Z8',
#   'I3L3N2',
#   'I3L465'],
#  'ENSG00000084731': ['O14782', 'F8WAR6', 'F8WER6'],
#  'ENSG00000103018': ['O43169',
#   'A0A8I5KP74',
#   'A0A8I5KSY3',
#   'A0A8I5KSY8',
#   'A0A8I5KVH4',
#   'A0A8I5KX20',
#   'A0A8I5KYK4',
#   'A0A8I5QJ67',
#   'A0A8I5QKN7',
#   'D6RFH4',
#   'H3BUX2',
#   'J3QR91'],
#  'ENSG00000176597': ['Q9BYG0', 'C9IYY0', 'C9J368', 'C9J5K2'],
#  'ENSG00000124145': ['P31431'],
#  'ENSG00000143367': ['Q9NNX1', 'A6PVU8'],
#  'ENSG00000102984': ['O75541',
#   'A0A087WXX1',
#   'A0A0C4DH12',
#   'H3BPS7',
#   'H3BQE4',
#   'H3BR59',
#   'H3BR75',
#   'H3BRD6',
#   'H3BS68',
#   'H3BTZ4',
#   'H3BVG7'],
#  'ENSG00000198879': ['Q5VUG0',
#   'A0A669KBL2',
#   'A0A804HJD5',
#   'A0A804HJE9',
#   'A0A804HK46',
#   'A0A804HKS4',
#   'A0A804HLD5',
#   'Q5T980',
#   'Q5T981'],
#  'ENSG00000204568': ['Q9Y676'],
#  'ENSG00000110244': ['P06727'],
#  'ENSG00000177272': ['P22001', 'A0A8V8TMD4'],
#  'ENSG00000177685': ['Q8N4Y2', 'E9PHZ8', 'E9PK04', 'E9PPF3', 'E9PRE5'],
#  'ENSG00000196422': ['Q5T8A7'],
#  'ENSG00000183715': ['Q14982'],
#  'ENSG00000107819': ['Q9BWM7', 'A0A8V8TM72', 'A0A8V8TP06', 'S4R3N9'],
#  'ENSG00000167797': ['O75956', 'E9PKR4', 'E9PQJ3'],
#  'ENSG00000120992': ['O75608',
#   'A0A087X1K9',
#   'B4DP64',
#   'E5RFT6',
#   'E5RGR0',
#   'E5RI35',
#   'E5RJ48'],
#  'ENSG00000211460': ['Q15631', 'A0A0J9YVW2', 'A0A0J9YX41', 'E9PGT1', 'H7C1D4'],
#  'ENSG00000149262': ['Q96HW7',
#   'A0A8C8UVZ7',
#   'A0A8Q3SHK8',
#   'A0A8Q3SHL8',
#   'A0A8Q3SHM4',
#   'A0A8Q3SHR8',
#   'A0A8Q3SHT4',
#   'A0A8Q3SHU3',
#   'A0A8Q3SII1',
#   'A0A8Q3WKB5',
#   'A0A8Q3WKB9',
#   'A0A8Q3WKC2',
#   'A0A8Q3WKC3',
#   'A0A8Q3WKC7',
#   'A0A8Q3WKC9',
#   'A0A8Q3WKW5',
#   'A0A8V8TLR7',
#   'E9PIM3',
#   'F8WAA7'],
#  'ENSG00000059573': ['P54886'],
#  'ENSG00000111335': ['P29728',
#   'A0A087X0V5',
#   'A0A7P0T8H9',
#   'A0A7P0T9B5',
#   'A0A7P0TAE6',
#   'A0A7P0TAV1',
#   'F8VPI5',
#   'F8W1C5'],
#  'ENSG00000196154': ['P26447'],
#  'ENSG00000069011': ['P78337', 'D6R955', 'D6R9U1'],
#  'ENSG00000108107': ['P46779', 'H0YKD8', 'H0YLP6', 'H0YMF4'],
#  'ENSG00000130528': ['P23327', 'M0QY84', 'M0QZ43'],
#  'ENSG00000124429': ['Q8WVV4'],
#  'ENSG00000130856': ['Q9UL36', 'A0A2R8YCW3', 'A0A994J512', 'J9JID5'],
#  'ENSG00000155755': ['Q96Q45', 'A0A087WWU1', 'F2Z329', 'F8WE96'],
#  'ENSG00000116752': ['O75934'],
#  'ENSG00000204463': ['P46379',
#   'A0A1B0GX79',
#   'A0A7I2V3H1',
#   'A0A7I2V508',
#   'A0A7P0MQS5',
#   'F6S6P2',
#   'F6TC96',
#   'F6U1F2',
#   'F6U341',
#   'F6UR09',
#   'F6VEM6',
#   'F6WML8',
#   'F6X9W3',
#   'F6XTU0',
#   'H0Y4L1',
#   'H0Y759',
#   'H0Y7K4',
#   'X6REW1'],
#  'ENSG00000131264': ['O14627'],
#  'ENSG00000140988': ['P15880',
#   'E9PM36',
#   'E9PMM9',
#   'E9PPT0',
#   'E9PQD7',
#   'H0YE27',
#   'H0YEN5',
#   'H3BNG3',
#   'I3L404'],
#  'ENSG00000135625': ['Q05215', 'A0A0C4DG96'],
#  'ENSG00000272414': ['D6RA91', 'F6W5V1'],
#  'ENSG00000236424': ['P0CW01', 'F2Z2I4'],
#  'ENSG00000181016': ['Q8N8F7'],
#  'ENSG00000095739': ['Q13145'],
#  'ENSG00000106144': ['P42575', 'A0A087WYM1', 'C9JRR9'],
#  'ENSG00000120094': ['P14653'],
#  'ENSG00000100227': ['Q9BY77', 'F6VRR5', 'F8WCX5', 'Q6R954'],
#  'ENSG00000168610': ['P40763',
#   'A0A7I2V2G1',
#   'A0A7I2V2T1',
#   'A0A7I2V395',
#   'A0A7I2V3V0',
#   'A0A7I2V444',
#   'A0A7I2V4C8',
#   'A0A7I2V4F6',
#   'A0A7I2V4R2',
#   'A0A7I2V4R3',
#   'A0A7I2V552',
#   'A0A7I2V5N9',
#   'A0A7I2YQD2',
#   'A0A7I2YQI1',
#   'A0A7I2YQR5',
#   'G8JLH9'],
#  'ENSG00000168329': ['P49238', 'C9JLM2', 'C9JN40'],
#  'ENSG00000122783': ['Q9BWK5', 'C9JKC7'],
#  'ENSG00000134253': ['Q9H8W5', 'H0YCA7', 'Q5T2K3', 'S4R407'],
#  'ENSG00000167098': ['Q8TC36', 'A9Z1W8', 'Q5TDX8', 'Q5TDX9'],
#  'ENSG00000182158': ['Q70SY1', 'C9JPH0', 'H7C1W8'],
#  'ENSG00000078814': ['Q5JW45', 'Q5JW46', 'Q5JW47', 'Q5JW48', 'Q5JW49'],
#  'ENSG00000104827': ['P0DN86'],
#  'ENSG00000181444': ['Q7Z7K2', 'C9JAX3'],
#  'ENSG00000147231': ['Q6NSI4', 'B1AQ74'],
#  'ENSG00000260027': ['P09629'],
#  'ENSG00000108551': ['Q9Y272'],
#  'ENSG00000128708': ['O14929', 'F8W9G7', 'F8WEW1'],
#  'ENSG00000174740': ['Q96DU9', 'Q5JQF3'],
#  'ENSG00000198894': ['Q9C0C6',
#   'G3V310',
#   'G3V3Y7',
#   'G3V405',
#   'G3V4V0',
#   'G3V5J4',
#   'G3V5Y7'],
#  'ENSG00000143889': ['Q8WVV9',
#   'B7WPG3',
#   'C9IYN3',
#   'C9JJZ7',
#   'H7BXH8',
#   'H7C464',
#   'V9GYK2'],
#  'ENSG00000164929': ['Q8WXS3'],
#  'ENSG00000182749': ['Q86WK9'],
#  'ENSG00000160055': ['Q8WY98', 'E9PNU5'],
#  'ENSG00000159352': ['P55036',
#   'A6PVX3',
#   'H0Y3Y9',
#   'H0Y561',
#   'H7C2J9',
#   'Q5VWC4'],
#  'ENSG00000182545': ['Q5GAN6'],
#  'ENSG00000172062': ['Q16637', 'B4DP61', 'E7EQZ4', 'H0YBZ9'],
#  'ENSG00000141255': ['Q8NHS9',
#   'F5GWB9',
#   'I3L1L5',
#   'I3L2B9',
#   'I3L3S6',
#   'I3L4D7',
#   'I3L4R7',
#   'I3L517'],
#  'ENSG00000171560': ['P02671'],
#  'ENSG00000112799': ['O95711'],
#  'ENSG00000242173': ['Q99819', 'A2ID99', 'C9J3B5'],
#  'ENSG00000150961': ['O94855',
#   'D6RAE2',
#   'D6RBM1',
#   'D6RGJ5',
#   'E9PC44',
#   'E9PDM8',
#   'E9PG84'],
#  'ENSG00000198783': ['Q96NB3', 'J3QQQ3'],
#  'ENSG00000223572': ['P12532', 'C9J8F6', 'C9JT96', 'F8WCN3', 'F8WDP9'],
#  'ENSG00000134072': ['Q14012', 'C9JES6', 'F8W6S9', 'H7C071'],
#  'ENSG00000142182': ['Q9UJW3', 'C9J0T5'],
#  'ENSG00000027644': ['P14616'],
#  'ENSG00000157734': ['Q96L94'],
#  'ENSG00000188612': ['P61956', 'J3KRH1'],
#  'ENSG00000183559': ['Q5SQS8', 'H0Y758'],
#  'ENSG00000100036': ['Q6ICL7', 'H7C3S2'],
#  'ENSG00000129151': ['O75936', 'E9PKC9'],
#  'ENSG00000188997': ['Q4G0X4',
#   'E9PJJ5',
#   'E9PK99',
#   'E9PM10',
#   'E9PMS5',
#   'E9PRT1'],
#  'ENSG00000130150': ['Q8NHP6', 'R4GMN1', 'R4GMW5', 'R4GNB6'],
#  'ENSG00000189042': ['Q8N184', 'F8WEL6', 'K7EMD5', 'K7ESK1'],
#  'ENSG00000111049': ['P13349'],
#  'ENSG00000164816': ['Q01523'],
#  'ENSG00000173221': ['P35754'],
#  'ENSG00000160049': ['O00273', 'K7ERT1'],
#  'ENSG00000120549': ['Q5T5P2',
#   'A0A0U1RQK8',
#   'A0A0U1RRK8',
#   'A0A1B0GU17',
#   'A0A8Q3WMI8',
#   'Q5T5P0',
#   'Q5T5P1'],
#  'ENSG00000149218': ['O94919'],
#  'ENSG00000197265': ['P29084', 'E5RH41', 'E5RIW4', 'E5RK24'],
#  'ENSG00000159495': ['Q96PF1'],
#  'ENSG00000160202': ['P02489', 'A0A8C8KJZ9', 'E7EWH7'],
#  'ENSG00000164035': ['Q9ULC0', 'D6RHW5', 'H0YAA7'],
#  'ENSG00000197798': ['Q9BPY3',
#   'E9PIM5',
#   'E9PMJ2',
#   'E9PMW3',
#   'G3V179',
#   'J3KP39'],
#  'ENSG00000107187': ['Q9UBR4', 'F1T0D7'],
#  'ENSG00000111231': ['Q9UHW5', 'F8W1F4', 'H0YHZ5', 'H0YI19', 'S4R3M7'],
#  'ENSG00000123395': ['Q9BSB4', 'F8VQD9', 'F8VVA0', 'H3BMZ4'],
#  'ENSG00000089639': ['Q9P107', 'K7EJC2', 'K7ELE8', 'K7EQR5'],
#  'ENSG00000163191': ['P31949'],
#  'ENSG00000140382': ['Q9NP66',
#   'H0YK55',
#   'H0YKL0',
#   'H0YKM5',
#   'H0YM80',
#   'H0YMG2',
#   'H0YMS9',
#   'H0YNS8'],
#  'ENSG00000171396': ['Q9BYR3'],
#  'ENSG00000198848': ['P23141', 'H3BQR4', 'H3BQV8', 'H3BSU0'],
#  'ENSG00000093144': ['Q9NTX5',
#   'E9PIU8',
#   'E9PJS8',
#   'E9PLY6',
#   'E9PPG7',
#   'E9PRU6',
#   'F2Z2D6',
#   'H0Y525',
#   'H0Y5L2',
#   'H0YCS9',
#   'H0YD54',
#   'J3KP84'],
#  'ENSG00000079277': ['Q9BUB5',
#   'A0A499FIS5',
#   'A0A499FJN1',
#   'A0A499FJS1',
#   'E9PIA0',
#   'E9PII5',
#   'E9PLE7',
#   'E9PMM8',
#   'E9PN34',
#   'E9PQ26',
#   'E9PSC9',
#   'E9PSE0',
#   'H0YE67',
#   'Q7Z319'],
#  'ENSG00000107262': ['Q99933',
#   'A0A0U1RR89',
#   'C9J9Y9',
#   'C9JYK5',
#   'F1LLU6',
#   'J3QTA2'],
#  'ENSG00000188986': ['Q8WX92', 'A0A5H1ZRP4'],
#  'ENSG00000154734': ['Q9UHI8',
#   'A0A7I2V400',
#   'A0A7I2V5J1',
#   'A0A7I2YQL5',
#   'E5RI60'],
#  'ENSG00000113924': ['Q93099', 'C9JTX9', 'H7C4R8', 'H7C576', 'H7C5G7'],
#  'ENSG00000166211': ['Q8N5J4'],
#  'ENSG00000143178': ['O60806', 'H0Y4B1', 'H0Y5A7'],
#  'ENSG00000182885': ['Q86Y34', 'F8W8F7', 'H3BRU4', 'H3BS78'],
#  'ENSG00000100221': ['Q15040',
#   'B0QY55',
#   'B0QY56',
#   'B0QY57',
#   'B0QY58',
#   'H0YGT9'],
#  'ENSG00000132341': ['P62826',
#   'A0A087X0W0',
#   'B4DV51',
#   'B5MDF5',
#   'F5H018',
#   'H0YFC6',
#   'J3KQE5'],
#  'ENSG00000204511': ['P59942'],
#  'ENSG00000148175': ['P27105', 'F8VSL7'],
#  'ENSG00000124444': ['Q9H609'],
#  'ENSG00000134825': ['P61165', 'F5GWH5', 'F5H7Z5'],
#  'ENSG00000186074': ['Q8TDQ1', 'J3KS52'],
#  'ENSG00000168710': ['O43865'],
#  'ENSG00000164287': ['Q86Y33'],
#  'ENSG00000090520': ['Q9UBS4', 'A0A7P0T9E8'],
#  'ENSG00000117408': ['O94829', 'Q5T4X2'],
#  'ENSG00000023608': ['Q16533'],
#  'ENSG00000101445': ['Q96T49'],
#  'ENSG00000183828': ['O95848', 'F8VU44'],
#  'ENSG00000055118': ['Q12809'],
#  'ENSG00000131871': ['Q9BQE4', 'A0A182DWI4', 'E9PN30'],
#  'ENSG00000244607': ['Q8IYE1'],
#  'ENSG00000180104': ['O60645', 'D6RB59', 'D6RBR9', 'H0Y995'],
#  'ENSG00000141646': ['Q13485',
#   'A0A087WUF3',
#   'K7EIJ2',
#   'K7EIU8',
#   'K7EL15',
#   'K7EL18',
#   'K7ELK2',
#   'K7ENG1',
#   'K7ES96'],
#  'ENSG00000110077': ['Q9H2W1',
#   'E9PJ78',
#   'E9PL03',
#   'E9PMN8',
#   'E9PNG6',
#   'E9PSA9',
#   'G5EA21',
#   'H0YEM2'],
#  'ENSG00000185630': ['P40424',
#   'A0A8V8TPF7',
#   'F8WA05',
#   'H0YKH1',
#   'H0YLB0',
#   'H0YLD4',
#   'H0YLF5',
#   'H0YLM3',
#   'H0YLT4',
#   'S4R377'],
#  'ENSG00000173269': ['Q9H8L6', 'R4GMY6', 'V9GY37', 'V9GY43', 'V9GYS9'],
#  'ENSG00000268350': ['Q8NDB6',
#   'A0A087WTI8',
#   'A0A087WVC3',
#   'A0A087WVC8',
#   'A0A087WY72',
#   'A0A087WZD0',
#   'A0A087WZZ1',
#   'A0A087X275',
#   'A0A087X2G5'],
#  'ENSG00000125875': ['Q96BZ9',
#   'A0A7P0T865',
#   'A0A7P0T876',
#   'A0A7P0T8Q3',
#   'A0A7P0T991',
#   'A0A7P0T9R2',
#   'A0A7P0TAF7',
#   'A0A7P0TBA8',
#   'A0A7P0TBI8'],
#  'ENSG00000166165': ['P12277',
#   'A0A0S2Z471',
#   'G3V2I1',
#   'G3V461',
#   'G3V4N7',
#   'H0YJG0',
#   'H0YJJ7',
#   'H0YJK0'],
#  'ENSG00000189319': ['Q14153'],
#  'ENSG00000179639': ['P12319', 'E9PRN1'],
#  'ENSG00000184988': ['Q96A25', 'B7Z779', 'K7ERE2'],
#  'ENSG00000174165': ['Q6UX98', 'E9PI61', 'E9PLR9'],
#  'ENSG00000171446': ['Q7Z3Y8'],
#  'ENSG00000213809': ['P26718', 'Q8WZ67'],
#  'ENSG00000087191': ['P62195',
#   'A0A994J3X6',
#   'A0A994J6H0',
#   'A0A994J6V8',
#   'J3KRP2',
#   'J3KTQ9',
#   'J3QLH6',
#   'J3QQM1',
#   'J3QRR3',
#   'J3QRW1',
#   'J3QSA9',
#   'J3QSE0'],
#  'ENSG00000103051': ['Q9H9E3',
#   'A0A0A0MS45',
#   'A0A6I8PIQ6',
#   'A0A8V8TQ33',
#   'A0A8V8TQ38',
#   'A0A8V8TQL5',
#   'A0A8V8TQL9',
#   'A0A8V8TQM1',
#   'A0A8V8TR60',
#   'A0A8V8TRG1',
#   'E9PRT5',
#   'H3BMV9',
#   'H3BQB2',
#   'H3BSD2',
#   'J3KNI1',
#   'J3KRB5',
#   'J3QLW1'],
#  'ENSG00000113558': ['P63208',
#   'E5RGM3',
#   'E5RGM4',
#   'E5RHM3',
#   'E5RJR5',
#   'E5RK33',
#   'E7ERH2',
#   'F8W8N3'],
#  'ENSG00000131469': ['P61353', 'K7ELC7', 'K7EQQ9', 'K7ERY7'],
#  'ENSG00000167588': ['P21695', 'F8VSE8'],
#  'ENSG00000143256': ['Q9UHV9'],
#  'ENSG00000118733': ['Q96PB7'],
#  'ENSG00000167600': ['Q96SQ9',
#   'M0QY51',
#   'M0QYI2',
#   'M0R057',
#   'M0R152',
#   'M0R2G8'],
#  'ENSG00000173540': ['Q9Y5P6',
#   'A0A7I2V2Y5',
#   'A0A7I2V4B5',
#   'A0A7I2V691',
#   'A0A7I2YQI5'],
#  'ENSG00000170175': ['P11230', 'I3L1T7', 'I3L3Q9', 'I3L4N5', 'I3L535'],
#  'ENSG00000146857': ['Q7Z7C7', 'A0A590UJF1', 'A0A590UK75'],
#  'ENSG00000106952': ['P32971', 'A0A087X228'],
#  'ENSG00000214706': ['Q12894', 'F8WEI6', 'H7C2Z4', 'H7C444'],
#  'ENSG00000259956': ['Q8NDT2'],
#  'ENSG00000073737': ['Q9BPW9', 'C9J430'],
#  'ENSG00000171444': ['P23508', 'A0A096LNU0', 'A0A096LPB3', 'D6REY2'],
#  'ENSG00000268629': ['Q9BXU3'],
#  'ENSG00000108829': ['Q96AG4', 'I3L223', 'I3L2E8'],
#  'ENSG00000156508': ['P68104',
#   'A0A087WV01',
#   'A0A087WVQ9',
#   'A0A7I2V3H3',
#   'A0A7I2V5N4',
#   'A0A7I2V659',
#   'A6PW80',
#   'Q5JR01'],
#  'ENSG00000174132': ['Q8TBP5'],
#  'ENSG00000100941': ['Q9H307', 'G3V579', 'G3V5F0'],
#  'ENSG00000177989': ['A8MYP8',
#   'A0A8C8KQ56',
#   'B5MC17',
#   'B5MCN9',
#   'B5MD02',
#   'C9JUR5'],
#  'ENSG00000143633': ['Q8NDD1', 'Q5TBH9', 'Q5TBI2'],
#  'ENSG00000141401': ['O14732',
#   'K7EIH6',
#   'K7EII9',
#   'K7EL65',
#   'K7ELF8',
#   'Q6PIP6'],
#  'ENSG00000181778': ['Q8N6L7'],
#  'ENSG00000155957': ['Q9HC24',
#   'E7EWY5',
#   'F5GXT9',
#   'F5H1S4',
#   'G3V1M2',
#   'G3V1R8',
#   'G3XAA5',
#   'Q7Z782'],
#  'ENSG00000174938': ['Q6UXD5', 'A0A087WYL5', 'H3BN26', 'I3L111'],
#  'ENSG00000023892': ['Q9H4E7', 'A0A8V8TMY0', 'A0A8V8TNX4', 'H0Y7V7'],
#  'ENSG00000259316': ['A0A0U1RQC1', 'A0A0U1RQM0', 'A0A0U1RQP9'],
#  'ENSG00000142875': ['P22694',
#   'A0A087WVC4',
#   'B1APF7',
#   'B1APF8',
#   'B1APF9',
#   'B1APG0',
#   'B1APG1',
#   'B1APG2',
#   'B1APG3'],
#  'ENSG00000106078': ['O75128',
#   'A0A0J9YWK3',
#   'A0A3B3IU00',
#   'C9J9X1',
#   'H7C1N2',
#   'J3KR05'],
#  'ENSG00000077800': ['O75344', 'A0A3B3IST2', 'C9JM01', 'F8WD36', 'F8WD38'],
#  'ENSG00000121905': ['P84074'],
#  'ENSG00000124232': ['Q9UBG7', 'A0A087X185', 'Q5QPV1'],
#  'ENSG00000124532': ['Q9HD23', 'A0A0A0MQX2', 'H7BZ29'],
#  'ENSG00000144028': ['O75643', 'A0A494C1A5'],
#  'ENSG00000136044': ['Q8NEU8',
#   'F8VR68',
#   'F8VS86',
#   'F8VWV2',
#   'F8VXB0',
#   'F8W124',
#   'H0YH86'],
#  'ENSG00000150477': ['Q86T90', 'K7EJ61', 'K7EM46', 'K7EP66', 'M0QYQ2'],
#  'ENSG00000142611': ['Q9HAZ2', 'D6RDW0', 'D6RFY3', 'H0YA13', 'U3KQL6'],
#  'ENSG00000175183': ['Q16527', 'F8VQR7', 'F8VW96'],
#  'ENSG00000104112': ['Q8WXD2', 'H0YKC2'],
#  'ENSG00000126391': ['Q9BZ67', 'E9PRA3', 'E9PRP1', 'E9PS62', 'Q8N4M4'],
#  'ENSG00000130669': ['O96013', 'M0R0L9', 'M0R1R1', 'M0R2X4', 'M0R3G6'],
#  'ENSG00000165698': ['Q96E40'],
#  'ENSG00000100425': ['O95696', 'J3KQ61'],
#  'ENSG00000118513': ['P10242',
#   'A0A087WTI6',
#   'A0A0C4DG19',
#   'E9PIW4',
#   'E9PJ96',
#   'E9PJF1',
#   'E9PJT2',
#   'E9PKZ3',
#   'E9PLN0',
#   'E9PMQ0',
#   'E9PMZ0',
#   'E9PN43',
#   'E9PN92',
#   'E9PNH6',
#   'E9PP87',
#   'E9PPL8',
#   'E9PPR4',
#   'E9PQQ2',
#   'F8W8G5',
#   'H0YCN6',
#   'Q708E3',
#   'Q708E6'],
#  'ENSG00000131037': ['Q8TE68', 'B4DKV7', 'K7EKX9', 'K7ELW3', 'K7EN83'],
#  'ENSG00000224470': ['P0C7T5'],
#  'ENSG00000024048': ['Q8IWV8'],
#  'ENSG00000118420': ['Q7Z6J8',
#   'D6RD24',
#   'D6RHY9',
#   'H0Y359',
#   'J3KMY4',
#   'Q4G0X5'],
#  'ENSG00000115593': ['Q8NB12', 'C9JUP3', 'E9PHG3'],
#  'ENSG00000163743': ['Q96PM5', 'D6RAF6', 'H0YAI4'],
#  'ENSG00000205572': ['O75920', 'D6RC42', 'D6RC90', 'D6RCL9'],
#  'ENSG00000175203': ['Q13561',
#   'A0A7I2V2Z2',
#   'A0A7I2V390',
#   'A0A7I2V4H4',
#   'A0A7I2V4Y9',
#   'A0A7I2V5R4',
#   'A8K8J9',
#   'F8VRV7',
#   'F8VW18',
#   'F8VX93',
#   'F8W0U6',
#   'F8W1I6',
#   'H0YHL1',
#   'H0YI98'],
#  'ENSG00000137221': ['Q5JTD0', 'A0A075B6G8', 'E2QRK7', 'H0Y4D6'],
#  'ENSG00000162928': ['Q92968', 'B5MBY9', 'D3YTD3', 'G5E9N6'],
#  'ENSG00000085382': ['Q8IYU2',
#   'E3W983',
#   'E5RFX0',
#   'E5RHI1',
#   'H0YAU8',
#   'H0YBH3',
#   'H0YC01',
#   'H0YC48'],
#  'ENSG00000105662': ['Q6UUV9', 'M0QX46', 'M0QXN6'],
#  'ENSG00000197123': ['Q8IYX0'],
#  'ENSG00000154710': ['Q9UJ41', 'A0A1W2PPY0', 'C9JDA2', 'E9PFK9', 'V9GYI8'],
#  'ENSG00000160284': ['Q9H0A9'],
#  'ENSG00000171970': ['Q68EA5', 'E5RHE3', 'G3V131', 'K7ERB8'],
#  'ENSG00000187790': ['Q8IYD8',
#   'A0A8Q3SIQ3',
#   'A0A8Q3SIT9',
#   'A0A8Q3SIU7',
#   'A0A8Q3SIU9',
#   'A0A8Q3SIV0',
#   'A0A8Q3SIX9',
#   'A0A8Q3SIZ4',
#   'A0A8Q3SJ05',
#   'A0A8Q3SJG0',
#   'A0A8Q3WLE8',
#   'A0A8Q3WLE9',
#   'A0A8Q3WLG0',
#   'A0A8Q3WLG3',
#   'A0A8Q3WLG5',
#   'A0A8Q3WLH1',
#   'A0A8Q3WLH2',
#   'A0A8Q3WLH3',
#   'A0A8Q3WLY4',
#   'A0A8Q3WLZ4',
#   'A0A8Q3WMJ4',
#   'A0A8Q3WMK3',
#   'H0YJ14',
#   'H0YJ45',
#   'H0YJN7',
#   'H0YJS3'],
#  'ENSG00000130561': ['P10523', 'C9JSX4', 'E7ESX4', 'F8WCN5'],
#  'ENSG00000072818': ['Q15027', 'I3L0K9', 'I3L268'],
#  'ENSG00000115216': ['Q9UHY1', 'C9JDW7', 'C9JHZ6', 'F8W6G1'],
#  'ENSG00000156697': ['Q9BVJ6', 'X6RJY0'],
#  'ENSG00000170180': ['P02724',
#   'A0A087WU29',
#   'A0A0C4DFT7',
#   'A0A2R8Y7F9',
#   'D6RJD8',
#   'E7EQF3',
#   'E9PD10',
#   'E9PH25',
#   'K9JI14',
#   'K9JIK7',
#   'Q13030'],
#  'ENSG00000076201': ['Q9H3S7', 'C9JD91', 'R4GMM7'],
#  'ENSG00000154997': ['Q6ZU15'],
#  'ENSG00000123411': ['Q9H2S9', 'A0A0G2JL44', 'F8VPL6', 'F8VW19'],
#  'ENSG00000130770': ['Q9UII2', 'A0A0B4J230'],
#  'ENSG00000141977': ['Q96Q77', 'M0QZ29'],
#  'ENSG00000189334': ['Q9HCY8'],
#  'ENSG00000176386': ['Q8NHZ8'],
#  'ENSG00000166317': ['Q9H987', 'U3KQD0'],
#  'ENSG00000186132': ['Q3KRA6', 'C9JTA8'],
#  'ENSG00000136950': ['Q9BPX5'],
#  'ENSG00000185670': ['Q9H5J0', 'A0A6E1W9L1', 'E9PPE9'],
#  'ENSG00000140575': ['P46940',
#   'A0A087WWP1',
#   'A0A087X225',
#   'A0A0J9YXZ5',
#   'H0YKA5',
#   'H0YLE8'],
#  'ENSG00000118181': ['P62851', 'E9PK60', 'E9PQK3'],
#  'ENSG00000166794': ['P23284', 'A0A7P0T7U3', 'A0A7P0TB45', 'A0A7P0Z497'],
#  'ENSG00000089685': ['O15392',
#   'A0A0B4J1S3',
#   'H3BLT4',
#   'K7ELG2',
#   'K7EMW2',
#   'K7EP76'],
#  'ENSG00000152078': ['Q96MV1', 'C9J6J2', 'C9JJM2'],
#  'ENSG00000102309': ['Q9Y237',
#   'A0A494C021',
#   'D6RFY5',
#   'H0Y4T6',
#   'H0Y610',
#   'H0Y8P6',
#   'J3KMW3'],
#  'ENSG00000151502': ['Q4G0F5', 'A0A0D9SFQ6', 'H0YCI7'],
#  'ENSG00000165694': ['Q6ZUT3', 'X6R7S7'],
#  'ENSG00000149591': ['Q01995', 'E9PJ32', 'H0YCU9'],
#  'ENSG00000151224': ['Q00266', 'B1ANE6'],
#  'ENSG00000104490': ['P61601',
#   'A0A1B0GXG3',
#   'E5RFL9',
#   'E5RGA9',
#   'E5RGZ0',
#   'E5RHC8',
#   'E5RHE8',
#   'E5RI78',
#   'E5RI95',
#   'E5RIA5',
#   'E5RIG4',
#   'E5RIX3',
#   'E5RIZ1',
#   'E5RJA1',
#   'E5RJF1',
#   'E5RJJ6',
#   'E5RJT1',
#   'E5RK89'],
#  'ENSG00000102387': ['Q5H9L4'],
#  'ENSG00000133193': ['Q969W3', 'J3KSI9', 'J3KT52', 'J3KT76'],
#  'ENSG00000153234': ['P43354',
#   'A0A8V8TPF8',
#   'A0A8V8TPV9',
#   'A0A8V8TR19',
#   'C9IYM5',
#   'C9J8W4',
#   'C9JWQ1',
#   'E9PBQ4',
#   'F1DAL2',
#   'F8W6I3'],
#  'ENSG00000124641': ['Q9H944', 'A6PVP4', 'B7ZBQ1', 'B7ZBQ3'],
#  'ENSG00000147127': ['Q5JT25', 'D6REW8'],
#  'ENSG00000244057': ['Q5T5A8'],
#  'ENSG00000143119': ['P19397'],
#  'ENSG00000166220': ['Q96M53', 'A0A0A0MSR7', 'A0A8I5KS30'],
#  'ENSG00000137312': ['O75955',
#   'A2AB09',
#   'A2AB10',
#   'A2AB11',
#   'A2AB12',
#   'A2AB13',
#   'A2ABJ5'],
#  'ENSG00000160753': ['Q9BVN2',
#   'A0A087WVK5',
#   'A0A087WW20',
#   'A0A087WX95',
#   'A0A087WYB2',
#   'A0A087WYU8',
#   'A0A087WZ68',
#   'A0A8Q3SIT1',
#   'Q68CX2'],
#  'ENSG00000165716': ['Q5VUD6'],
#  'ENSG00000243279': ['O60831', 'A6NP52'],
#  'ENSG00000078369': ['P62873',
#   'A0A994J3T6',
#   'A0A994J6X8',
#   'B1AKQ8',
#   'B3KVK2',
#   'F6UT28',
#   'F6X3N5'],
#  'ENSG00000187583': ['Q494U1', 'J3KSM5'],
#  'ENSG00000178252': ['Q9NNW5',
#   'A0A087X295',
#   'C9JFP6',
#   'C9K020',
#   'E5RFX3',
#   'E9PBK6',
#   'E9PDU5',
#   'F8WE36',
#   'V9GYU1',
#   'V9GZ48',
#   'V9GZ65'],
#  'ENSG00000129472': ['Q8WUD1', 'A0A3B3ITL1', 'E9PE37'],
#  'ENSG00000136754': ['Q8IZP0', 'A0A0A0MRT6', 'B6VEX4'],
#  'ENSG00000019995': ['Q9UGI0'],
#  'ENSG00000186272': ['P17021', 'M0QZR3', 'M0R2T2'],
#  'ENSG00000125991': ['Q9Y282',
#   'A0A0C4DH46',
#   'A6PVJ2',
#   'H0Y5K5',
#   'H0Y621',
#   'H0Y6Z0',
#   'H0Y802'],
#  'ENSG00000180219': ['Q8NEG0'],
#  'ENSG00000092531': ['O00161',
#   'H3BM38',
#   'H3BNE1',
#   'H3BNG6',
#   'H3BP15',
#   'H3BPJ0',
#   'H3BQY9',
#   'H3BR18',
#   'H3BR99',
#   'H3BU94',
#   'H3BV99'],
#  'ENSG00000206530': ['Q96MT7',
#   'A0A1D5RMR1',
#   'C9K0A4',
#   'F8WEX0',
#   'H0Y883',
#   'H0Y896',
#   'H7C512',
#   'H7C591'],
#  'ENSG00000170465': ['P48668'],
#  'ENSG00000206559': ['Q504Y3', 'C9JFK0', 'H7C087', 'H7C0K4', 'H7C0L9'],
#  'ENSG00000141013': ['O95995',
#   'A0A087WZT7',
#   'H3BME0',
#   'H3BP65',
#   'H3BQT7',
#   'H3BUA7'],
#  'ENSG00000164972': ['Q8NCR6', 'A0A8I5KRB0'],
#  'ENSG00000125850': ['Q9BRP0'],
#  'ENSG00000129493': ['Q86XA9',
#   'F5H619',
#   'F8VQQ6',
#   'H0YHE0',
#   'H0YHS5',
#   'H0YIW3',
#   'H7C5W6'],
#  'ENSG00000164683': ['Q9Y5J3',
#   'A0A6I8PIY0',
#   'A0A6I8PRC2',
#   'A0A6I8PRS3',
#   'A0A6I8PU82',
#   'E5RHK6'],
#  'ENSG00000177673': ['Q53QW1'],
#  'ENSG00000205899': ['Q7RTU4'],
#  'ENSG00000104957': ['P13994', 'K7EJZ6', 'K7ELI4', 'K7EP29', 'K7ES43'],
#  'ENSG00000169032': ['Q02750',
#   'A0A8I5KRX5',
#   'A0A8I5KVF6',
#   'A0A8I5KXN4',
#   'A0A8I5KYB4',
#   'A0A8I5KYS7',
#   'A0A8I5QJ96',
#   'A0A8I5QJC1',
#   'A0A8I5QJL9',
#   'A0A8I5QJP8',
#   'B4DFY5',
#   'H3BRW9'],
#  'ENSG00000070366': ['Q86US8',
#   'I3L176',
#   'I3L1W8',
#   'I3L355',
#   'I3L390',
#   'I3L3A9',
#   'I3L421',
#   'K7EKV2',
#   'K7ELM2',
#   'K7ENH7'],
#  'ENSG00000163518': ['Q96PJ5'],
#  'ENSG00000221909': ['Q8TCP9', 'J3QT35'],
#  'ENSG00000204628': ['P63244',
#   'D6R909',
#   'D6R9L0',
#   'D6R9Z1',
#   'D6RAC2',
#   'D6RAU2',
#   'D6RBD0',
#   'D6RDI0',
#   'D6REE5',
#   'D6RF23',
#   'D6RFX4',
#   'D6RFZ9',
#   'D6RGK8',
#   'D6RHH4',
#   'D6RHJ5',
#   'E9PD14',
#   'H0Y8R5',
#   'H0Y8W2',
#   'H0Y9P0',
#   'H0YAF8',
#   'H0YAM7',
#   'J3KPE3'],
#  'ENSG00000102103': ['O60828', 'A0A5H1ZRR1', 'H7C053'],
#  'ENSG00000072958': ['Q9BXS5',
#   'A0A087WZX7',
#   'E7ENJ6',
#   'K7EJL1',
#   'K7ENA7',
#   'K7EPJ8',
#   'K7EQ90',
#   'K7EQX3',
#   'K7ER75'],
#  'ENSG00000108468': ['P83916', 'B5MD17', 'C9JWS9', 'J3KS05', 'K7ELA4'],
#  'ENSG00000188315': ['Q6ZUJ4', 'C9JW57', 'H7BZX3'],
#  'ENSG00000171055': ['Q9UHY8',
#   'F8W6C0',
#   'F8WB37',
#   'G3V0F5',
#   'H7C0L4',
#   'H7C0W1',
#   'H7C434',
#   'Q7Z674'],
#  'ENSG00000204449': ['P0CI26'],
#  'ENSG00000013288': ['Q9Y2E5', 'E9PCD7', 'H0YA68'],
#  'ENSG00000168079': ['Q6ZMJ2'],
#  'ENSG00000097033': ['Q9Y371', 'A0A087WW40', 'A0A994J549'],
#  'ENSG00000100151': ['Q9NRD5',
#   'E7EX80',
#   'F6TII1',
#   'F6V107',
#   'F6V3V1',
#   'F6VY12'],
#  'ENSG00000100228': ['O95755', 'H7C0Z1'],
#  'ENSG00000123562': ['Q15014', 'Q5JXX1', 'Q5JXX2', 'Q5JXX6'],
#  'ENSG00000177710': ['Q96KT7'],
#  'ENSG00000143198': ['O14880', 'Q5VV87', 'Q5VV89'],
#  'ENSG00000197024': ['Q8TD17'],
#  'ENSG00000166323': ['Q8NCR3', 'E9PQ22', 'H0YD27'],
#  'ENSG00000177301': ['P16389',
#   'A0A1W2PP65',
#   'A0A1W2PPM7',
#   'A0A1W2PPN8',
#   'A0A1W2PR01',
#   'A0A1W2PRY2'],
#  'ENSG00000256453': ['Q8IYX4'],
#  'ENSG00000129566': ['Q99973',
#   'G3V2A4',
#   'G3V470',
#   'G3V591',
#   'G3V5X7',
#   'H0YIY9',
#   'H0YIZ2',
#   'H0YJ53',
#   'H0YJF6',
#   'H0YJP8'],
#  'ENSG00000160285': ['P48449', 'C9J315', 'H7C3A5'],
#  'ENSG00000161921': ['Q9H2A7', 'A0A6I8PIU7', 'I3L333'],
#  'ENSG00000184014': ['Q6IQ26',
#   'A0A7P0T8L1',
#   'A0A7P0T8L8',
#   'A0A7P0T9H0',
#   'A0A7P0T9Z2',
#   'A0A7P0TAA7',
#   'A0A7P0TAF6',
#   'A0A7P0TAH5',
#   'A0A7P0Z4N9',
#   'B4DFB6',
#   'E9PIS3',
#   'H0YCW5',
#   'H0YDS8',
#   'H0YDV6',
#   'H0YEA8'],
#  'ENSG00000204580': ['Q08345',
#   'A0A0A0MSX3',
#   'A2ABL0',
#   'A2ABL2',
#   'A2ABM8',
#   'D6R9C4',
#   'D6RAJ3',
#   'D6RB35',
#   'D6RB82',
#   'D6RBU7',
#   'D6RGW5',
#   'E7EN94',
#   'E7ENJ2',
#   'E7EPH4',
#   'E7EPN2',
#   'E7EQ23',
#   'E7EQ30',
#   'E7ERI6',
#   'E7ERN0',
#   'E7ES06',
#   'E7ESR9',
#   'E7ETI3',
#   'E7ETX3',
#   'E7EUD5',
#   'E7EUP7',
#   'E7EVT1',
#   'E7EVW6',
#   'E7EX99',
#   'E7EXB0',
#   'H0Y717',
#   'H0Y9F4',
#   'H0YAH6'],
#  'ENSG00000005102': ['P50221'],
#  'ENSG00000049759': ['Q96PU5',
#   'A0A087WVI6',
#   'A0A140TA85',
#   'A0A1B0GVY1',
#   'A0A6Q8PFI7',
#   'A0A6Q8PG51',
#   'A0A6Q8PG81',
#   'A0A6Q8PGL4',
#   'A0A6Q8PGP5',
#   'A0A6Q8PHE7',
#   'A0A6Q8PHJ5',
#   'A0A7P0Z498',
#   'K7EKL1',
#   'K7EN51',
#   'K7ENS6',
#   'K7EQC5',
#   'K7ERN1'],
#  'ENSG00000111596': ['Q9NZN8',
#   'A0A087X050',
#   'F8VPX5',
#   'F8VQD8',
#   'F8VQF4',
#   'F8VRJ3',
#   'F8VRS8',
#   'F8VS14',
#   'F8VSK9',
#   'F8VUB4',
#   'F8VV05',
#   'F8VV52',
#   'F8VVD4',
#   'F8VVY1',
#   'F8VWH8',
#   'F8VX63',
#   'F8W145',
#   'H0YH84',
#   'H0YHT6',
#   'H0YHT8',
#   'H0YI11',
#   'H0YI80'],
#  'ENSG00000130511': ['Q9BWG4',
#   'M0R338',
#   'U3KPY3',
#   'U3KQ46',
#   'U3KQ98',
#   'U3KQN6',
#   'U3KQP2',
#   'V9GYB2'],
#  'ENSG00000077092': ['P10826',
#   'A0A8I5KNZ0',
#   'A0A8I5KQX3',
#   'A0A8I5KSR9',
#   'A0A8I5KUH8',
#   'A0A8I5KVJ9',
#   'A0A8I5KVN9',
#   'A0A8I5KVP8',
#   'A0A8I5KWP3',
#   'A0A8I5KXD0',
#   'A0A8I5KXT3',
#   'D6RBI3'],
#  'ENSG00000143842': ['Q9UN79', 'E9PKD6', 'E9PPW0', 'H0YDQ5'],
#  'ENSG00000075975': ['Q9H000',
#   'A0A7I2V388',
#   'A0A7I2V422',
#   'A0A7I2V4L9',
#   'A0A7I2V5D2',
#   'A0A7I2YQI0',
#   'C9J494'],
#  'ENSG00000169302': ['Q8WU08', 'A0A3B3IS85', 'B7Z9H7'],
#  'ENSG00000124067': ['Q9UP95',
#   'A0A994J5J8',
#   'I3L1N8',
#   'I3L4N6',
#   'J3QKM4',
#   'J3QRE2',
#   'J3QSF2'],
#  'ENSG00000141873': ['Q9BRY0', 'F5H385', 'K7EJZ1', 'K7ENJ1'],
#  'ENSG00000213416': ['Q9BQ66'],
#  'ENSG00000066735': ['Q9ULI4', 'A0A8V8TM02', 'C9JFF0'],
#  'ENSG00000133250': ['Q96IQ9', 'M0R0Q5', 'M0R1G8', 'M0R2Q9', 'M0R398'],
#  'ENSG00000184979': ['Q9UMW8', 'A0A8V8TMN0'],
#  'ENSG00000154359': ['Q17RB8', 'A0A0C4DGE8', 'E9PQH4', 'E9PRX6', 'H7C5V9'],
#  'ENSG00000136152': ['Q96JB2', 'A0A087WTH9', 'A0A087WYY9'],
#  'ENSG00000134717': ['Q96K17', 'E9PL10', 'E9PPC3'],
#  'ENSG00000140932': ['Q8TAZ6', 'H3BMC0'],
#  'ENSG00000183010': ['P32322',
#   'E2QRB3',
#   'J3KQ22',
#   'J3KSA9',
#   'J3KTA8',
#   'J3QKT3',
#   'J3QKT4',
#   'J3QL23',
#   'J3QL24',
#   'J3QL32',
#   'J3QLK9',
#   'J3QR88',
#   'J3QRZ0'],
#  'ENSG00000124827': ['O75603'],
#  'ENSG00000174903': ['Q9H0U4', 'E9PLD0'],
#  'ENSG00000115963': ['P61587', 'E9PFH1', 'Q53RZ3'],
#  'ENSG00000185522': ['Q8IXW0', 'C9JV74', 'E9PJR3'],
#  'ENSG00000158406': ['P62805'],
#  'ENSG00000156097': ['Q9BZJ8', 'A0A8I5KY74'],
#  'ENSG00000159592': ['Q9HC44'],
#  'ENSG00000168453': ['O43593', 'E5RK80'],
#  'ENSG00000166448': ['Q8N3G9', 'C9JQV5', 'G3V0E7'],
#  'ENSG00000153495': ['Q8N6K0', 'F2Z350'],
#  'ENSG00000128536': ['Q6ZTQ4',
#   'E7EQG5',
#   'E9PEI5',
#   'F8WF00',
#   'H7C548',
#   'H7C555'],
#  'ENSG00000109061': ['P12882'],
#  'ENSG00000080572': ['Q9NQM4', 'A0A8I5QJ82'],
#  'ENSG00000125735': ['O43557'],
#  'ENSG00000185917': ['Q9NVD3',
#   'A8MTS1',
#   'C9J256',
#   'C9JIU9',
#   'C9JPA1',
#   'C9JWV5',
#   'C9JYV0'],
#  'ENSG00000167671': ['Q9BZV1', 'K7EJ02', 'K7ELN1', 'K7EP32'],
#  'ENSG00000113494': ['P16471',
#   'D6R9E1',
#   'D6R9P5',
#   'D6R9V7',
#   'D6RAN9',
#   'D6RC67',
#   'D6RD41',
#   'D6RJC8'],
#  'ENSG00000179564': ['Q8N112'],
#  'ENSG00000180787': ['Q96NJ6'],
#  'ENSG00000204351': ['Q15477',
#   'A0A8V8TL97',
#   'A0A8V8TLA2',
#   'A0A8V8TLC0',
#   'A0A8V8TLR3',
#   'A0A8V8TMR3',
#   'A0A8V8TN04',
#   'B4E0B4',
#   'F8WDE8',
#   'H7C4L3',
#   'H7C5N0'],
#  'ENSG00000105700': ['Q9BQD3',
#   'M0QX74',
#   'M0QXN9',
#   'M0QXP3',
#   'M0QY77',
#   'M0R0B4',
#   'M0R228',
#   'M0R2G3'],
#  'ENSG00000179528': ['Q6XYB7', 'G3V218'],
#  'ENSG00000032389': ['Q53HC9',
#   'A8MUM1',
#   'C9J0U9',
#   'C9JVR6',
#   'D3YTH5',
#   'F8WB12',
#   'F8WDS8',
#   'F8WDX0'],
#  'ENSG00000123992': ['Q9ULA0',
#   'B9ZVU2',
#   'C9J1E2',
#   'C9JBE1',
#   'C9JRG3',
#   'E3W974',
#   'E3W979',
#   'E5RHR3',
#   'E5RIA4',
#   'E5RJ35',
#   'E7EMB6',
#   'E7EPX3',
#   'E7ETB3',
#   'F8WAN0'],
#  'ENSG00000166387': ['Q8ND30',
#   'A0A3B3IS15',
#   'A0A804HJY3',
#   'A0A804HKA2',
#   'E9PI79',
#   'E9PIK8',
#   'E9PJA0',
#   'E9PK17',
#   'E9PMH3',
#   'E9PMN3',
#   'E9PP16',
#   'H0YDJ2',
#   'H0YDM0',
#   'H0YET1'],
#  'ENSG00000120896': ['O60504',
#   'E5RIA0',
#   'E5RJP2',
#   'E7EQH0',
#   'H0YAU6',
#   'H0YAZ3',
#   'H0YB51'],
#  'ENSG00000136999': ['P48745'],
#  'ENSG00000174738': ['Q14995', 'Q6NSM0'],
#  'ENSG00000100083': ['Q9UJY5',
#   'B0QYR5',
#   'B0QYR6',
#   'B0QYR8',
#   'B0QYR9',
#   'B0QYS0',
#   'B0QYS1',
#   'B0QYS2',
#   'B0QYS3',
#   'B0QYS5'],
#  'ENSG00000141526': ['O15427',
#   'J3KTI8',
#   'J3KTM6',
#   'J3QQS9',
#   'J3QQV2',
#   'J3QRA0',
#   'J3QRP8',
#   'J3QSC3'],
#  'ENSG00000186599': ['Q8NG35'],
#  'ENSG00000250565': ['Q96A05'],
#  'ENSG00000198818': ['Q8WV19'],
#  'ENSG00000163527': ['Q8TCJ2'],
#  'ENSG00000180398': ['Q8NI22', 'A0A3B3IU18', 'C9JTR4', 'H7BZ18'],
#  'ENSG00000172409': ['Q92989', 'E9PJM4', 'E9PKV5', 'E9PL17'],
#  'ENSG00000204498': ['Q9UBC1', 'A0A0A0MRT5', 'F2Z390', 'Q5STV6'],
#  'ENSG00000142230': ['Q9UBE0',
#   'A0A590UK93',
#   'A0A590UKA0',
#   'A0A590UKC5',
#   'B3KNJ4',
#   'M0QX65',
#   'M0QYM8',
#   'M0QYP2',
#   'M0QZS6',
#   'M0R054',
#   'M0R286',
#   'M0R375'],
#  'ENSG00000020129': ['Q9UBB6', 'C9J5H8', 'H7C2R2'],
#  'ENSG00000138750': ['Q7Z3B4',
#   'A0A8Q3SHX2',
#   'A0A8Q3SI16',
#   'A0A8Q3WKJ4',
#   'A0A8Q3WKK2',
#   'A0A8Q3WKL3',
#   'A0A8Q3WKP8',
#   'A0A8Q3WL42',
#   'A0A8Q3WLP2',
#   'A0A8Q3WLY5',
#   'A0A8Z5F6C8',
#   'D6RB65',
#   'D6RBF7',
#   'D6RFI8'],
#  'ENSG00000185359': ['O14964',
#   'A0A7I2V2D8',
#   'A0A7I2V2K1',
#   'A0A7I2V2K2',
#   'A0A7I2V2M1',
#   'A0A7I2V2M4',
#   'A0A7I2V2R9',
#   'A0A7I2V2W5',
#   'A0A7I2V307',
#   'A0A7I2V310',
#   'A0A7I2V319',
#   'A0A7I2V331',
#   'A0A7I2V363',
#   'A0A7I2V3A5',
#   'A0A7I2V3C3',
#   'A0A7I2V3E9',
#   'A0A7I2V3F9',
#   'A0A7I2V3I8',
#   'A0A7I2V3J3',
#   'A0A7I2V3L0',
#   'A0A7I2V3N6',
#   'A0A7I2V3Q7',
#   'A0A7I2V3Z1',
#   'A0A7I2V468',
#   'A0A7I2V4J7',
#   'A0A7I2V4M9',
#   'A0A7I2V4X6',
#   'A0A7I2V4Z5',
#   'A0A7I2V558',
#   'A0A7I2V569',
#   'A0A7I2V5A2',
#   'A0A7I2V5A3',
#   'A0A7I2V5B7',
#   'A0A7I2V5C4',
#   'A0A7I2V5D6',
#   'A0A7I2V5E5',
#   'A0A7I2V5E7',
#   'A0A7I2V5L9',
#   'A0A7I2V5N3',
#   'A0A7I2V5V1',
#   'A0A7I2V5W6',
#   'A0A7I2V5X2',
#   'A0A7I2V605',
#   'A0A7I2V611',
#   'A0A7I2V616',
#   'A0A7I2V628',
#   'A0A7I2V637',
#   'A0A7I2V674',
#   'A0A7I2V6E0',
#   'A0A7I2YQD1',
#   'A0A7I2YQH7',
#   'A0A7I2YQM4',
#   'A0A7I2YQM9',
#   'A0A7I2YQP0',
#   'A0A7I2YQS8',
#   'A0A7I2YQU5',
#   'A0A7I2YQY0',
#   'I3L165',
#   'I3L1E3',
#   'I3L1F1',
#   'I3L1P5',
#   'I3L2H4',
#   'I3L326',
#   'I3L346'],
#  'ENSG00000163492': ['Q6ZP82', 'A0A0A6YYF7', 'B8ZZB3', 'C9JR62'],
#  'ENSG00000229183': ['P0DJD7', 'F5GXL4', 'F5H0H6'],
#  'ENSG00000163281': ['Q8TDQ7', 'V9GYK3', 'V9GYW0'],
#  'ENSG00000132470': ['P16144', 'J3KSH9', 'J3QQL2', 'J3QRK0'],
#  'ENSG00000100280': ['Q10567', 'C9J1E7', 'H7C034'],
#  'ENSG00000110344': ['Q14139', 'B7Z7P0'],
#  'ENSG00000185238': ['O60678', 'E9PLF6', 'E9PRB4'],
#  'ENSG00000149716': ['Q8WV07',
#   'A6YPU5',
#   'B4DFA5',
#   'F5GWS9',
#   'F5GZY6',
#   'F5H179',
#   'F5H6T8',
#   'F5H8D9',
#   'H3BPK6'],
#  'ENSG00000153558': ['Q9UKC9',
#   'F8WB01',
#   'F8WBS9',
#   'F8WBW7',
#   'F8WC58',
#   'F8WCQ8',
#   'F8WE99'],
#  'ENSG00000189190': ['Q6ZNG1', 'A0A3B3IT03', 'A0A3B3ITH4', 'A0A3B3ITY9'],
#  'ENSG00000113441': ['Q9UIQ6'],
#  'ENSG00000138100': ['Q9BYV2'],
#  'ENSG00000118816': ['Q14094',
#   'D6RDK3',
#   'D6REZ3',
#   'D6RG12',
#   'D6RH01',
#   'H0YA27'],
#  'ENSG00000188732': ['A4D161', 'B8ZZQ8', 'F8WCP2', 'F8WCP3'],
#  'ENSG00000180611': ['Q8IYB1'],
#  'ENSG00000164326': ['Q16568'],
#  'ENSG00000274808': ['A6NDS4', 'A0A087WU82', 'A0A087WVG1'],
#  'ENSG00000102870': ['Q9UEG4'],
#  'ENSG00000102401': ['Q9UH62', 'H3BM63', 'H3BV87'],
#  'ENSG00000070031': ['P09683'],
#  'ENSG00000165072': ['Q7Z304'],
#  'ENSG00000198612': ['Q99627', 'E9PGT6', 'F8WEF2', 'H7C3S9'],
#  'ENSG00000148735': ['Q5SXH7',
#   'A0A494C040',
#   'A0A494C1H5',
#   'A0A8Q3WKA6',
#   'H7BZQ2'],
#  'ENSG00000134690': ['Q53HL2'],
#  'ENSG00000176055': ['Q68D91'],
#  'ENSG00000070010': ['Q92890', 'C9IZG3', 'C9J6N9', 'C9J7C8', 'C9JNP9'],
#  'ENSG00000175809': ['Q8N7E2'],
#  'ENSG00000166523': ['Q9ULY5', 'F5H5X7', 'F8WFA1', 'H0YGH9'],
#  'ENSG00000171502': ['Q17RW2', 'E9PNK8', 'F8WDM8', 'H0YCZ7'],
#  'ENSG00000163006': ['Q96M89', 'F8WF51', 'H7BZ08', 'H7C005', 'V9GZ19'],
#  'ENSG00000161888': ['Q8NBT2',
#   'A0A0A0MSN0',
#   'K7EJH0',
#   'K7EJV2',
#   'K7EMX1',
#   'K7ERQ7',
#   'K7ESQ2'],
#  'ENSG00000091317': ['Q9NX76'],
#  'ENSG00000174808': ['P35070', 'H0Y8Q5'],
#  'ENSG00000166925': ['Q9Y3Q8', 'H7BZ77', 'H7C0M8'],
#  'ENSG00000164188': ['Q86VV4', 'D6RCM9'],
#  'ENSG00000154917': ['Q9NRW1', 'C9J0I2', 'C9JB90', 'C9JU14', 'J3KR73'],
#  'ENSG00000173452': ['Q5HYL7', 'B7WNR7', 'F8WE15'],
#  'ENSG00000109445': ['Q9Y3S2',
#   'D6R8Y9',
#   'D6R9C8',
#   'D6RBR7',
#   'D6RBS7',
#   'D6RCK7'],
#  'ENSG00000169756': ['P48059',
#   'A0A0M3HER1',
#   'A0A8Q3WKI3',
#   'A0A8Q3WKJ2',
#   'A0A8Q3WKK6',
#   'A0A8Q3WKP0',
#   'A0A8Q3WLN4',
#   'A0A8Q3WLX8',
#   'F8WB59',
#   'F8WC86',
#   'F8WE10'],
#  'ENSG00000010361': ['Q9BT04',
#   'E9PK12',
#   'E9PKJ4',
#   'E9PLA3',
#   'E9PS25',
#   'G5E9A4',
#   'M0QYI7',
#   'M0QYX9',
#   'M0QZY8',
#   'M0R0M0',
#   'M0R1D4'],
#  'ENSG00000164111': ['P08758', 'D6RBE9', 'D6RBL5', 'D6RCN3', 'E9PHT9'],
#  'ENSG00000019582': ['P04233', 'E7EQJ3', 'H0YBZ2', 'H0YBZ8'],
#  'ENSG00000072042': ['Q8TC12',
#   'G3V234',
#   'G3V2G6',
#   'G3V3K0',
#   'G3V510',
#   'H0YJ46'],
#  'ENSG00000128016': ['P26651', 'M0QY76', 'M0R252'],
#  'ENSG00000204279': ['Q5JUK9'],
#  'ENSG00000117122': ['P55001'],
#  'ENSG00000276070': ['Q8NHW4'],
#  'ENSG00000175782': ['Q7Z769', 'A0A669KB01', 'A0A669KB59'],
#  'ENSG00000164896': ['Q14296'],
#  'ENSG00000129351': ['Q12906',
#   'K7EJ09',
#   'K7EKJ9',
#   'K7EKY0',
#   'K7ELV3',
#   'K7EM82',
#   'K7EMZ8',
#   'K7ENK6',
#   'K7EPG3',
#   'K7EQ75',
#   'K7EQR9',
#   'K7ER69',
#   'K7ERM6'],
#  'ENSG00000197728': ['P62854'],
#  'ENSG00000141101': ['Q9ULX3', 'H3BUR4'],
#  'ENSG00000162881': ['Q8TDS5'],
#  'ENSG00000113163': ['Q9Y5P4',
#   'A0A0A0MRE4',
#   'A0A2R8Y3S9',
#   'A0A2R8Y5G0',
#   'A0A2R8Y5H3',
#   'A0A2R8Y5S9',
#   'A0A2R8Y773',
#   'A0A2R8Y7C5',
#   'A0A2R8Y7Q9',
#   'A0A2R8YCI0',
#   'A0A2R8YDX6',
#   'A0A2R8YE18',
#   'A0A2R8YE59',
#   'A0A2R8YEA4',
#   'A0A2R8YEK8',
#   'A0A2R8YFA1',
#   'A0A2R8YFI2',
#   'A0A2U3TZL3',
#   'H0Y9J1'],
#  'ENSG00000173253': ['Q9Y5R5', 'A0A0A0MR18'],
#  'ENSG00000158639': ['Q96GU1', 'Q5JUL1'],
#  'ENSG00000162961': ['Q9C005'],
#  'ENSG00000073921': ['Q13492',
#   'E9PI56',
#   'E9PJT1',
#   'E9PK13',
#   'E9PKP6',
#   'E9PLJ8',
#   'H0YCY1',
#   'H0YD48',
#   'H0YE97',
#   'H0YEF7',
#   'H0YEH1',
#   'H0YEY8'],
#  'ENSG00000126860': ['P22794'],
#  'ENSG00000166743': ['Q08AH1', 'E5RFK0', 'H0YAU5'],
#  'ENSG00000188393': ['Q6UVW9'],
#  'ENSG00000165714': ['Q969J3', 'G3V1P3'],
#  'ENSG00000136110': ['O75829', 'E9PKI9'],
#  'ENSG00000143340': ['Q96GL9'],
#  'ENSG00000164011': ['Q5VV52', 'A0A0A0MRR1', 'Q5VV50', 'Q5VV51'],
#  'ENSG00000115290': ['Q14449', 'C9JD37', 'C9JLT6'],
#  'ENSG00000115239': ['Q9Y575', 'H7BYZ6'],
#  'ENSG00000163430': ['Q12841', 'C9J5G4', 'H7C4W4'],
#  'ENSG00000106459': ['Q16656', 'C9JP85'],
#  'ENSG00000173846': ['Q9H4B4'],
#  'ENSG00000205659': ['B3KN83', 'G3V5T8'],
#  'ENSG00000184838': ['Q569H4', 'A0A0A0MSW7', 'D6RGF0'],
#  'ENSG00000173638': ['P41440',
#   'C9J8K6',
#   'C9JKP4',
#   'E9PIL5',
#   'H0Y4T2',
#   'H3BTQ3'],
#  'ENSG00000158552': ['Q8WV99',
#   'A0A087X0D9',
#   'B4DEN4',
#   'B8ZZ56',
#   'C9J1R6',
#   'E7EV05',
#   'E9PFU9',
#   'F8WEE4',
#   'H7C491'],
#  'ENSG00000128641': ['O43795',
#   'A0A0U1RRI3',
#   'C9JUP5',
#   'C9JYW1',
#   'C9K0I9',
#   'E7EQD9',
#   'E9PDF6',
#   'H7C2Y7'],
#  'ENSG00000111364': ['Q8NHQ9', 'E7EX41', 'F5H2I2', 'F5H5U2', 'F5H735'],
#  'ENSG00000278318': ['Q9UJW7', 'A0A087WVZ7', 'A0A087X068', 'K7EIU9'],
#  'ENSG00000197976': ['Q02040', 'X6RAJ1'],
#  'ENSG00000278828': ['P68431'],
#  'ENSG00000142494': ['Q96FL8', 'E7EX57', 'I3L345', 'J3KRZ3', 'J3KSS8'],
#  'ENSG00000160058': ['Q9NW68', 'E9PNA9', 'E9PQA7', 'E9PS77', 'F8W6C6'],
#  'ENSG00000173641': ['Q9UBY9', 'C9J5A3', 'D3YTC6', 'Q68DG0', 'Q8N241'],
#  'ENSG00000221978': ['Q96S94', 'C9J148', 'J3KRL1', 'J3QSH2'],
#  'ENSG00000121039': ['Q8IZV5', 'E5RHJ9', 'E5RK48'],
#  'ENSG00000141985': ['Q99961', 'M0QYE0', 'M0R0I3', 'M0R2K6'],
#  'ENSG00000175582': ['P20340', 'F5GX61', 'F5H3K7'],
#  'ENSG00000154127': ['Q8TF42'],
#  'ENSG00000178381': ['Q8N6M9', 'A8MYA3', 'I3L1X3', 'J3KQ25'],
#  'ENSG00000127578': ['Q96NZ8'],
#  'ENSG00000198887': ['Q8IY18'],
#  'ENSG00000099814': ['Q9Y4F5'],
#  'ENSG00000127054': ['Q5TA45',
#   'A0A087WXT8',
#   'A0A087WYI0',
#   'C9IYS7',
#   'C9J979',
#   'E9PI75',
#   'E9PIG1',
#   'E9PIL7',
#   'E9PIS0',
#   'E9PIX9',
#   'E9PJG0',
#   'E9PKA4',
#   'E9PMA2',
#   'E9PNH9',
#   'E9PNS4',
#   'E9PQF0',
#   'H0YDB1',
#   'H0YE15',
#   'H0YEQ9',
#   'H7C247',
#   'J3QRY6'],
#  'ENSG00000167741': ['Q6P531', 'B4DPG6', 'I3L2G6', 'J3KPJ0'],
#  'ENSG00000185019': ['O94941', 'A2A2Q6'],
#  'ENSG00000161011': ['Q13501',
#   'C9J6J8',
#   'C9JRJ8',
#   'D6RBF1',
#   'E3W990',
#   'E7EMC7',
#   'E9PFW8'],
#  'ENSG00000197343': ['Q8N720',
#   'C9IYG2',
#   'C9J0V9',
#   'C9J9R2',
#   'C9JNK1',
#   'C9JS03',
#   'C9JUB9',
#   'F8WCS2',
#   'F8WDU5',
#   'F8WE52',
#   'F8WEB1'],
#  'ENSG00000100784': ['O75582', 'A0A3B3ISL8', 'G3V2D1', 'G3V4D7', 'H0YJE1'],
#  'ENSG00000153029': ['Q95460', 'A0A804HIG0', 'A0A804HJC9', 'A0A8C8PVM5'],
#  'ENSG00000179335': ['P49761',
#   'H3BNC8',
#   'H3BNQ5',
#   'H3BQG1',
#   'H3BQR7',
#   'H3BRE4',
#   'H3BRK0',
#   'H3BRT8',
#   'H3BRW2',
#   'H3BTW9',
#   'H3BUL5',
#   'H3BV35',
#   'H3BVF8'],
#  'ENSG00000215269': ['P0CL81'],
#  'ENSG00000134909': ['A7KAX9', 'A0A804HK06', 'E9PRH3', 'G3V174'],
#  'ENSG00000182134': ['Q9Y2W6', 'B7ZAG4', 'E9PKN8', 'E9PQX4', 'Q5SZR4'],
#  'ENSG00000254901': ['Q96FH0', 'K7ENY0', 'U3KPZ4'],
#  'ENSG00000187091': ['P51178'],
#  'ENSG00000067836': ['Q9GZN7',
#   'K7EID1',
#   'K7EJ96',
#   'K7EL91',
#   'K7EMJ5',
#   'K7EPN1',
#   'K7EPS3',
#   'K7ERN3',
#   'K7ERP1'],
#  'ENSG00000135775': ['Q14746', 'B7Z2Y2', 'V9GY21'],
#  'ENSG00000103154': ['Q7Z6G3', 'H3BPH6', 'H3BQC7'],
#  'ENSG00000159167': ['P52823'],
#  'ENSG00000164164': ['Q01804', 'D6RA27', 'D6RI06'],
#  'ENSG00000132017': ['Q66K64', 'K7ELE9', 'K7ENG0', 'K7ERN0'],
#  'ENSG00000165695': ['Q96MA6'],
#  'ENSG00000127989': ['Q99551', 'B4DPR9', 'C9JE25', 'C9JNM8', 'C9JU79'],
#  'ENSG00000204897': ['Q7Z3Z0'],
#  'ENSG00000165322': ['Q8IWW6', 'H0Y5D8', 'Q1RLN5'],
#  'ENSG00000198829': ['Q9BXA5'],
#  'ENSG00000100678': ['P57103', 'F2Z391'],
#  'ENSG00000108786': ['P14061', 'A0A0A0MQS7', 'B4DU11'],
#  'ENSG00000023330': ['P13196', 'H7C4H7', 'H7C5B0'],
#  'ENSG00000196646': ['P52737', 'A0A494C0J2', 'C9J2Q9', 'C9JJK8', 'C9JR58'],
#  'ENSG00000087274': ['P35611',
#   'A0A804HL01',
#   'D6RAH3',
#   'D6RF25',
#   'D6RJE2',
#   'E7ENY0',
#   'E7EV99',
#   'H0Y9H2',
#   'H0YFD8',
#   'H0YG19'],
#  'ENSG00000268320': ['P0DMR2'],
#  'ENSG00000158079': ['A2A3K4', 'A0A087WTF0'],
#  'ENSG00000124508': ['Q8WVV5',
#   'C9IY66',
#   'C9IZY2',
#   'C9J8J5',
#   'C9J8R3',
#   'C9JAJ6',
#   'C9JWH2',
#   'F8WC65',
#   'H7C4E8'],
#  'ENSG00000188026': ['Q5EBL4', 'A0A1B0GVV3'],
#  'ENSG00000169045': ['P31943',
#   'A0A9L9PY23',
#   'D6R9D3',
#   'D6RAM1',
#   'D6RBM0',
#   'D6RDL0',
#   'D6RDU3',
#   'D6RF17',
#   'D6RFM3',
#   'D6RIT2',
#   'D6RIU0',
#   'E5RGV0',
#   'E5RJ94',
#   'E7EN40',
#   'E7EQJ0',
#   'E9PCY7',
#   'G8JLB6',
#   'H0YAQ2',
#   'H0YB39',
#   'H0YBD7',
#   'H0YBK1',
#   'H0YBW2'],
#  'ENSG00000079432': ['Q96RK0',
#   'A0A0A0MQR4',
#   'A0A7P0T9K5',
#   'I3L135',
#   'I3L1Q4',
#   'I3L2J0',
#   'I3L373'],
#  'ENSG00000160050': ['Q9BUN5', 'A0A7P0TB33', 'E9PM81'],
#  'ENSG00000140368': ['O43586',
#   'B4E1Z9',
#   'H0YKF1',
#   'H0YKY3',
#   'H0YLI2',
#   'H0YLM9',
#   'H0YLW8',
#   'H0YLX8',
#   'H0YNR2',
#   'H0YNS1',
#   'J3KPG6'],
#  'ENSG00000157870': ['Q8TBF2',
#   'A0A0A0MRV4',
#   'A0A0A0MT35',
#   'A0A2P0CTH9',
#   'J3KRV9',
#   'J3QKK8'],
#  'ENSG00000054654': ['Q8WXH0',
#   'A0A0C4DGK3',
#   'A0A1W2PRN9',
#   'A0A1W2PS37',
#   'A0A669KB22',
#   'A0A669KB61',
#   'A0A669KBG2',
#   'A0A669KBH2',
#   'G3V2Q0',
#   'G3V3D4',
#   'G3V4T3',
#   'G3V5N1',
#   'G3V5X4'],
#  'ENSG00000105568': ['P30153',
#   'A0A994J3H1',
#   'A0A994J3N8',
#   'A0A994J6A3',
#   'B3KQV6',
#   'C9J9C1',
#   'E9PH38',
#   'M0QXG4',
#   'M0R0K6'],
#  'ENSG00000186141': ['Q9BUI4',
#   'A0A8V8TM54',
#   'A0A8V8TM82',
#   'A0A8V8TMN9',
#   'A0A8V8TNN2',
#   'E9PHH9'],
#  'ENSG00000172336': ['O75817', 'C9JYM0'],
#  'ENSG00000140365': ['Q9H0A8',
#   'A0A0B4J287',
#   'H3BM91',
#   'H3BPG2',
#   'H3BQF2',
#   'H3BRX0',
#   'H3BTV9'],
#  'ENSG00000121335': ['P02812', 'H3BR58'],
#  'ENSG00000157379': ['Q96LJ7', 'H0YNC2'],
#  'ENSG00000108559': ['Q99567',
#   'A0A8V8TPS0',
#   'A0A8V8TPS5',
#   'A0A8V8TPT0',
#   'A0A8V8TPT4',
#   'A0A8V8TQA5',
#   'A0A8V8TQB1',
#   'A0A8V8TQB7',
#   'A0A8V8TQC2',
#   'A0A8V8TQC3',
#   'A0A8V8TQC7',
#   'A0A8V8TQD1',
#   'A0A8V8TQD5',
#   'A0A8V8TQZ0',
#   'A0A8V8TQZ4',
#   'A0A8V8TQZ7',
#   'A0A8V8TR00',
#   'A0A8V8TRA1',
#   'A0A8V8TRA5',
#   'A0A8V8TRA7',
#   'I3L245',
#   'I3L2W3',
#   'I3L4K7',
#   'J3KMX1'],
#  'ENSG00000124357': ['Q9UJ70',
#   'C9JEV6',
#   'C9JMR7',
#   'E9PPU6',
#   'H0YC94',
#   'H0YE82',
#   'H0YEB7',
#   'H0YF44',
#   'H7C1L7',
#   'H7C286',
#   'H7C3G9'],
#  'ENSG00000145439': ['Q8N4T8', 'D6RAV8', 'D6RGF2', 'D6RJF4', 'H0Y962'],
#  'ENSG00000125046': ['Q9Y2M2',
#   'A0A8V8TMK3',
#   'C9JAQ0',
#   'F8WDP2',
#   'F8WDV4',
#   'F8WED9',
#   'G5E9S6'],
#  'ENSG00000152332': ['Q8TAS1'],
#  'ENSG00000136938': ['Q92688'],
#  'ENSG00000165915': ['Q96H72',
#   'E9PNE7',
#   'E9PNN7',
#   'E9PRH4',
#   'E9PSA8',
#   'G3V1B2',
#   'K4DIA9',
#   'K4DIB5'],
#  'ENSG00000214447': ['A6NFU0'],
#  'ENSG00000171823': ['Q8N1E6'],
#  'ENSG00000099282': ['O95858', 'H7C285'],
#  'ENSG00000136146': ['Q9NPJ6', 'A0A087X0U0', 'Q5T911'],
#  'ENSG00000111077': ['Q63HR2', 'F8VV64', 'H0YID7', 'R4GMX1'],
#  'ENSG00000143374': ['Q9BW92', 'Q5T5E9', 'U3KQ50', 'U3KQG0'],
#  'ENSG00000214944': ['Q8N1W1', 'D6RAP0', 'D6RGZ3'],
#  'ENSG00000106829': ['Q04727',
#   'A0A0A0MT79',
#   'A0A994J7T6',
#   'E7EQH3',
#   'F8WAY5',
#   'H0Y5S0',
#   'H7C4E4',
#   'H7C4P7',
#   'H7C4W5',
#   'Q5JSY7',
#   'Q5JSY8',
#   'Q5JSZ1',
#   'Q5JSZ2'],
#  'ENSG00000213185': ['Q8N5W8'],
#  'ENSG00000244476': ['P60508'],
#  'ENSG00000160688': ['Q8NFF5', 'Q5T190', 'Q5T191', 'Q5T196'],
#  'ENSG00000066557': ['Q9H9A6'],
#  'ENSG00000125734': ['Q9NPR9',
#   'G5E9L6',
#   'M0QYF6',
#   'M0QZ03',
#   'M0QZW9',
#   'M0QZY1',
#   'M0R1G1',
#   'M0R1Q3',
# ...
#  'ENSG00000139291': ['Q96HH6', 'F8VRE8', 'F8VS20', 'H0YHY1', 'H0YIS8'],
#  'ENSG00000240045': ['P0DN84'],
#  'ENSG00000169385': ['P10153'],
#  'ENSG00000166200': ['P61201', 'B4DIH5', 'H0YKU5', 'H0YM03', 'H0YMC2'],
#  'ENSG00000164330': ['Q9UH73', 'E5RFQ1'],
#  'ENSG00000172732': ['Q96NY9',
#   'E9PII7',
#   'E9PL60',
#   'E9PRI1',
#   'H0YDE3',
#   'H0YDK3',
#   'H0YDU2',
#   'H0YE94'],
#  'ENSG00000181031': ['Q9UNE2',
#   'I3L181',
#   'I3L1Q0',
#   'I3L2G8',
#   'I3L2I9',
#   'I3L2N0',
#   'I3L2W0',
#   'I3L2X0',
#   'I3L308',
#   'I3L349',
#   'I3L3M9',
#   'I3NI49'],
#  'ENSG00000138035': ['Q8TCS8', 'F8WBI3', 'H7BXF6', 'H7C3C5'],
#  'ENSG00000137393': ['Q7Z419'],
#  'ENSG00000130598': ['P48788'],
#  'ENSG00000166997': ['Q8N129', 'A0A0J9YXE1', 'A0A0J9YYJ0'],
#  'ENSG00000256646': ['A0A024RA52', 'A0A7I2V2H3', 'A0A7I2YQP7', 'H3BT36'],
#  'ENSG00000164118': ['Q9C0F1', 'D6RBX1', 'D6RC25', 'D6RGX6'],
#  'ENSG00000268988': ['Q5MJ10'],
#  'ENSG00000064012': ['Q14790',
#   'A0A8Q3SI66',
#   'A0A8Q3SID9',
#   'A0A8Q3WKY8',
#   'C9JB29',
#   'E7EQ01',
#   'E7EQ06',
#   'E7ETB7',
#   'E7EVN1',
#   'F8WF39',
#   'H7C0E2'],
#  'ENSG00000196456': ['Q96BV0', 'C9JAM7', 'C9JVG2'],
#  'ENSG00000198183': ['Q9NP55'],
#  'ENSG00000155158': ['Q5VTQ0',
#   'A0A8V8N5K5',
#   'A0A8V8NCV2',
#   'A0A8V8PNE1',
#   'H0YAJ6'],
#  'ENSG00000147394': ['O15231', 'A0A8Q3WKR1', 'H0Y704', 'H7BZT5', 'H7C1R1'],
#  'ENSG00000166069': ['Q8N6Q1',
#   'H0YL40',
#   'H0YLD3',
#   'H0YLN2',
#   'H0YLW5',
#   'H0YMD4'],
#  'ENSG00000114735': ['Q9Y5R4', 'F2Z2F0', 'H7C258'],
#  'ENSG00000087111': ['Q96S52',
#   'A0A994J546',
#   'A0A994J550',
#   'A0A994J555',
#   'A0A994J5E2',
#   'A0A994J5E6',
#   'A0A994J5F0',
#   'A0A994J5F5',
#   'A0A994J5S0',
#   'A0A994J5S5',
#   'A0A994J5S7',
#   'A0A994J7M3',
#   'A0A994J7M6',
#   'A0A994J7M9',
#   'A0A994J801',
#   'A0A994J804',
#   'A0A994J808',
#   'A0A994J810',
#   'H0Y2N5',
#   'J3QL67',
#   'K7EN97'],
#  'ENSG00000178934': ['P47929'],
#  'ENSG00000159788': ['O14924', 'A0A2R8YCJ1', 'E9PBG5'],
#  'ENSG00000139233': ['Q9BRT6'],
#  'ENSG00000102312': ['Q9H237', 'C9JWI5', 'F2Z360', 'F8WEW7'],
#  'ENSG00000172586': ['Q96BP2', 'A6NJX6'],
#  'ENSG00000079102': ['Q06455',
#   'A0A0A0MSU1',
#   'A0A1B0GX92',
#   'E5RFQ3',
#   'E5RG85',
#   'E5RH30',
#   'E5RH72',
#   'E5RHJ8',
#   'E5RI38',
#   'E5RJ32',
#   'E5RJB3',
#   'E5RJE7',
#   'E5RK76',
#   'E7EQ59',
#   'E7EQI9',
#   'E7EQJ1',
#   'E7EQW3',
#   'E7EQW7',
#   'E7ERJ9',
#   'E7ESA9',
#   'E7ESL1',
#   'E7ETA8',
#   'E7EWJ9',
#   'E7EX23',
#   'H0YBA6',
#   'H0YC25',
#   'H0YC43'],
#  'ENSG00000278588': ['P62807'],
#  'ENSG00000003056': ['P20645',
#   'F5GX30',
#   'F5GXE0',
#   'F5GXU0',
#   'F5H4U1',
#   'F5H883',
#   'H0YF90',
#   'H0YFL0',
#   'H0YFY9',
#   'H0YGE9',
#   'H0YGT2'],
#  'ENSG00000151692': ['P50876', 'C9JLH4', 'H7C3G0'],
#  'ENSG00000101871': ['O15344',
#   'A0A087X255',
#   'A0A6Q8PF94',
#   'A0A6Q8PGA5',
#   'A0A6Q8PGE7',
#   'A0A8I5KPB2',
#   'A0A8I5KPE0',
#   'A0A8I5KR14',
#   'C9J453'],
#  'ENSG00000166595': ['Q9Y3D0', 'H3BNV7', 'J3KS95', 'J3QLT9'],
#  'ENSG00000166527': ['Q8WXI8', 'A6NHA5'],
#  'ENSG00000186280': ['Q6B0I6'],
#  'ENSG00000179580': ['Q2KHN1', 'A0A0C4DFQ4', 'H3BNJ8'],
#  'ENSG00000167333': ['Q6AZZ1', 'E9PJJ9', 'E9PP83', 'E9PR29'],
#  'ENSG00000115267': ['Q9BYX4', 'A0A3B3IRK8', 'A0A7P0Z4A9', 'A0A8V8TKX2'],
#  'ENSG00000068985': ['O75459'],
#  'ENSG00000071242': ['Q15349',
#   'B7Z3B5',
#   'D6R910',
#   'D6RA62',
#   'D6RD75',
#   'D6RE03',
#   'D6RHW7',
#   'F2Z2J1'],
#  'ENSG00000066136': ['Q13952',
#   'A0A0A0MT00',
#   'E9PI99',
#   'E9PJA8',
#   'E9PL11',
#   'E9PQR2',
#   'H0Y803',
#   'Q5T6K5',
#   'Q5T6K7'],
#  'ENSG00000105088': ['O95897', 'K7EIS8', 'K7EKW2', 'K7ELC6'],
#  'ENSG00000213923': ['P49674',
#   'A0A669KBC0',
#   'B0QY34',
#   'B0QY35',
#   'B0QY36',
#   'H0Y5S9',
#   'H0Y645',
#   'H0Y682',
#   'H7C0Y5',
#   'H7C3J2'],
#  'ENSG00000138069': ['P62820', 'E7END7'],
#  'ENSG00000152242': ['Q96B23', 'A0A087WVF1', 'K7EQH1', 'K7ER64'],
#  'ENSG00000137656': ['Q9BRD0', 'H7C462'],
#  'ENSG00000149657': ['Q9BX40', 'A0A0C4DFV2', 'Q5TBP9', 'Q5TBQ0', 'Q5TBQ1'],
#  'ENSG00000083896': ['Q96MU7', 'J3KRG5', 'J3KRW0', 'J3KS01', 'J3QR07'],
#  'ENSG00000197062': ['Q16670',
#   'A0A024RCN4',
#   'A0A087WXH0',
#   'A0A087X2F1',
#   'B4DMT1'],
#  'ENSG00000112531': ['Q96PU8',
#   'F5GXS8',
#   'F5GYM3',
#   'F5GYT7',
#   'F5H5U6',
#   'F5H8C8',
#   'H0YFB7',
#   'H0YG47',
#   'H0YGD6'],
#  'ENSG00000012061': ['P07992',
#   'A0AA34QVL1',
#   'K7EJL2',
#   'K7EJW9',
#   'K7EK97',
#   'K7EMT9',
#   'K7EP14',
#   'K7ER60',
#   'K7ER89',
#   'K7ES46'],
#  'ENSG00000188343': ['A1XBS5',
#   'A0A0B4J212',
#   'E5RFH7',
#   'E5RFS7',
#   'E5RGD0',
#   'E5RGE3',
#   'E5RGP4',
#   'E5RHA4',
#   'E5RHK0',
#   'E5RID3',
#   'F8W7P5',
#   'H0YC32'],
#  'ENSG00000164123': ['Q96LM5'],
#  'ENSG00000143450': ['Q9UMX2',
#   'A0A0G2JH29',
#   'A0A0U1RR57',
#   'A0A0U1RRA2',
#   'A8MW57',
#   'H0Y7Y4',
#   'J3QLT2',
#   'Q5SZR7'],
#  'ENSG00000120832': ['Q49AM1', 'F8VSD8', 'F8VSL4', 'F8VXH5'],
#  'ENSG00000101882': ['Q8N5F7', 'A0A494C050'],
#  'ENSG00000104129': ['Q9NVM6', 'H0YK99', 'H0YLQ7', 'H0YLV4', 'S4R343'],
#  'ENSG00000177551': ['Q02577', 'A6PVY9'],
#  'ENSG00000115919': ['Q16719',
#   'A0A087WYM2',
#   'A0A087WYQ7',
#   'A0A087X297',
#   'B8ZZA3',
#   'F8WEP1'],
#  'ENSG00000101997': ['O60826'],
#  'ENSG00000116717': ['P24522', 'A0A087WZQ0', 'A0A3B3ITF9', 'A5JUZ3'],
#  'ENSG00000126259': ['Q6UWL6', 'A0A0A0MQV3', 'A0A0A0MRC1', 'K7EJS8', 'V9GXZ7'],
#  'ENSG00000163069': ['Q16585', 'H0Y8J3', 'H0YA15'],
#  'ENSG00000145191': ['Q13144',
#   'A0A3B3IRP4',
#   'A0A3B3IS56',
#   'A0A3B3ISA5',
#   'A0A3B3ISI2',
#   'A0A3B3ISM8',
#   'A0A3B3ISS1',
#   'A0A3B3IST9',
#   'A0A3B3ISV1',
#   'A0A3B3ISX3',
#   'A0A3B3IT53',
#   'A0A3B3ITG6',
#   'A0A3B3ITK8',
#   'A0A3B3ITQ2',
#   'A0A3B3IUB1',
#   'A0A3B3IUF2',
#   'C9JRD9',
#   'H7C2X0'],
#  'ENSG00000167992': ['Q96DN2', 'B4DS56', 'B4DY31'],
#  'ENSG00000006611': ['Q9Y6N9', 'E9PNW1'],
#  'ENSG00000174453': ['B2RUY7', 'B7ZW27'],
#  'ENSG00000132541': ['P52758', 'E5RIP8', 'H0YB34', 'H0YBX3'],
#  'ENSG00000170166': ['P09016'],
#  'ENSG00000101213': ['Q13882'],
#  'ENSG00000172785': ['Q9BRT8',
#   'A0A087WTC0',
#   'A0A087WU37',
#   'A0A087WVU7',
#   'A0A087WWK6',
#   'A0A087WY70',
#   'A0A087WZQ3',
#   'A0A087X0Y9',
#   'A0A087X140',
#   'A0A087X1Y1',
#   'A0A0B4J1T6',
#   'F2Z2T4'],
#  'ENSG00000141965': ['Q9BSK4'],
#  'ENSG00000154124': ['Q96BN8', 'A0A8V8TKZ0', 'D6RD57', 'H0Y8S4', 'H0Y9T0'],
#  'ENSG00000154518': ['P48201'],
#  'ENSG00000134597': ['Q9Y388', 'Q5JY83'],
#  'ENSG00000157349': ['Q9UMR2',
#   'H3BMQ5',
#   'H3BMV7',
#   'H3BPV3',
#   'H3BQK0',
#   'H3BTX1',
#   'H3BUH0'],
#  'ENSG00000132768': ['Q9BQC3',
#   'E9PIY4',
#   'E9PJH6',
#   'E9PLL2',
#   'E9PMH7',
#   'E9PPU3',
#   'H0YCR5'],
#  'ENSG00000011243': ['Q9ULX6',
#   'A0A7P0T847',
#   'A0A7P0T8N3',
#   'A0A7P0T9N5',
#   'A0A7P0TAD3',
#   'A0A7P0TAE3',
#   'A0A7P0TAJ5',
#   'A0A7P0TBP0',
#   'M0QYT7',
#   'M0R008',
#   'M0R010',
#   'M0R1L5',
#   'M0R1Y5',
#   'V9GZ50'],
#  'ENSG00000124702': ['Q9BQ90', 'F8W6A4'],
#  'ENSG00000110245': ['P02656', 'B0YIW2', 'C9J2Q0'],
#  'ENSG00000144579': ['Q9GZU7', 'A0AA34QVU0', 'A0AA34QW09', 'H7C270'],
#  'ENSG00000169715': ['P04732', 'H3BU80'],
#  'ENSG00000205002': ['Q4LEZ3'],
#  'ENSG00000110844': ['Q6NWY9', 'A0A8Z5ADK7', 'F8VU11', 'H0YII7'],
#  'ENSG00000185818': ['Q8N9F0'],
#  'ENSG00000114544': ['Q96GZ6',
#   'D6R925',
#   'D6R9M9',
#   'D6R9S7',
#   'D6R9X6',
#   'D6RC02',
#   'D6RDB0',
#   'D6RDM3',
#   'D6RF72',
#   'D6RHE3',
#   'D6RJC0'],
#  'ENSG00000139318': ['Q16828', 'F8VW29', 'F8VZA4'],
#  'ENSG00000143436': ['Q9BYD2',
#   'A0A1W2PPE5',
#   'A0A1W2PPK1',
#   'A0A1W2PQB6',
#   'A0A1W2PRK9',
#   'A0A1W2PS92',
#   'Q5SZR1'],
#  'ENSG00000176490': ['O95057', 'K7EN06'],
#  'ENSG00000100299': ['P15289', 'A0A0C4DFZ2', 'V9GYR0'],
#  'ENSG00000196391': ['Q6NX45', 'E7EQ77', 'H0YLG8', 'H0YNW6'],
#  'ENSG00000185177': ['Q96JC4'],
#  'ENSG00000078061': ['P10398'],
#  'ENSG00000135144': ['Q86Y01'],
#  'ENSG00000129675': ['Q15052'],
#  'ENSG00000198373': ['O00308', 'H3BPJ8', 'H3BRX8', 'H3BS79'],
#  'ENSG00000168394': ['Q03518',
#   'A0A2R8Y4Y0',
#   'A0A8V8TLN3',
#   'A0A8V8TLQ7',
#   'A0A8V8TM76',
#   'A0A8V8TN61',
#   'A0A8V8TNH0'],
#  'ENSG00000119541': ['O75351', 'K7EKZ3', 'K7EL71'],
#  'ENSG00000109270': ['Q9UHA4'],
#  'ENSG00000127324': ['P19075'],
#  'ENSG00000160207': ['O75031', 'C9JSF2'],
#  'ENSG00000108821': ['P02452', 'I3L3H7'],
#  'ENSG00000106246': ['O75127', 'C9JGL8', 'C9JQN9', 'C9JWL7'],
#  'ENSG00000178343': ['A0PJX4'],
#  'ENSG00000164530': ['Q6UXB8'],
#  'ENSG00000137265': ['Q15306', 'A0A8Q3WLL3', 'A0A8Q3WLQ3', 'F2Z3D5'],
#  'ENSG00000151923': ['Q01085', 'A0A087WX93', 'A6NKZ9', 'E7ETC0', 'E7ETJ9'],
#  'ENSG00000162739': ['Q96DU3'],
#  'ENSG00000111666': ['Q8WUD6', 'F8W1B3', 'H0YHV7', 'H0YI24', 'H0YI84'],
#  'ENSG00000160679': ['Q9Y3Y2', 'A0A087X1B7', 'A0AA34QVV3', 'Q5T7Y7', 'X6R700'],
#  'ENSG00000161860': ['Q6PIF2', 'K7EM50'],
#  'ENSG00000204435': ['P67870',
#   'A0A7I2V500',
#   'A0A7I2YQ78',
#   'A0A7I2YQQ2',
#   'Q5SRQ6'],
#  'ENSG00000166170': ['Q9UL15'],
#  'ENSG00000163535': ['Q562F6', 'C9JW92'],
#  'ENSG00000198574': ['O14796'],
#  'ENSG00000109118': ['Q96QT6',
#   'C9J9G2',
#   'J3QQU3',
#   'K7EJ43',
#   'K7EJN7',
#   'K7EJY3',
#   'K7EMX6',
#   'K7ENU0',
#   'K7EPF7',
#   'K7EQP5',
#   'K7ERZ4'],
#  'ENSG00000171357': ['Q96LR2'],
#  'ENSG00000227234': ['Q9NS25'],
#  'ENSG00000168763': ['Q8NE01'],
#  'ENSG00000005249': ['P31323', 'A0A9L9PXN2'],
#  'ENSG00000204475': ['O14931'],
#  'ENSG00000154832': ['Q9P0U4',
#   'A0A669KB29',
#   'A0A669KB50',
#   'K7EJR0',
#   'K7EKZ6',
#   'K7EQ21',
#   'K7EQZ1'],
#  'ENSG00000172845': ['Q02447',
#   'A0A494C070',
#   'A0A494C0Z6',
#   'A0A494C1G8',
#   'H0Y6K5',
#   'H0Y7L6'],
#  'ENSG00000147654': ['O00559',
#   'A0A8V8TNL5',
#   'A0A8V8TPH5',
#   'E9PJ38',
#   'E9PJ40',
#   'E9PN10',
#   'E9PND3'],
#  'ENSG00000137700': ['U3KPU7', 'U3KQL4', 'U3KQS2'],
#  'ENSG00000204370': ['O14521', 'A0A1W2PNY0', 'E9PK73', 'G3V173', 'H0YD96'],
#  'ENSG00000095066': ['Q96ED9',
#   'A0A7I2V5Y2',
#   'K7EJ48',
#   'K7EJ65',
#   'K7EJA7',
#   'K7EK29',
#   'K7EMG7',
#   'K7EMR5',
#   'K7ENU5'],
#  'ENSG00000244242': ['A6NMD0', 'H0Y3H0'],
#  'ENSG00000050426': ['Q6P1Q0',
#   'F8VP71',
#   'F8VPY5',
#   'F8VQE7',
#   'F8VR33',
#   'F8VR35',
#   'F8VS60',
#   'F8VTR1',
#   'F8VUZ8',
#   'F8VVQ3',
#   'F8VXQ4',
#   'F8VZA2',
#   'F8W0R0',
#   'F8W1U1',
#   'F8W1Z2',
#   'F8W6J0',
#   'F8WCD9',
#   'H0YH93',
#   'H0YHF4',
#   'H0YIV5'],
#  'ENSG00000155530': ['Q96M69', 'A0A2R8YEJ5', 'A0A8Q3SI13', 'A0A8Q3SIT3'],
#  'ENSG00000169583': ['O95833'],
#  'ENSG00000275126': ['P62805'],
#  'ENSG00000112378': ['Q96FX8'],
#  'ENSG00000141971': ['Q96EY5',
#   'E9PJW8',
#   'E9PLL0',
#   'E9PLZ8',
#   'E9PQA6',
#   'M0QZK6'],
#  'ENSG00000176463': ['Q9UIG8', 'G3V2B7', 'G3V3K4', 'H0YJM0'],
#  'ENSG00000111832': ['Q9H446', 'E5RGQ3', 'E5RGS5', 'E5RJE3'],
#  'ENSG00000198003': ['A5D8V7', 'K7EN59', 'K7EPB4', 'K7EPK8'],
#  'ENSG00000168216': ['Q9NUN5',
#   'A0A3B3IRL1',
#   'A0A3B3IRN0',
#   'A0A3B3IRS7',
#   'A0A3B3IS10',
#   'A0A3B3IS99',
#   'A0A3B3IT31',
#   'A0A3B3IT65',
#   'A0A3B3ITM4',
#   'A0A3B3ITP2',
#   'A0A3B3ITR7',
#   'A0A3B3IU68',
#   'A0A3B3IU91',
#   'A0A3B3IU99',
#   'A0A3F2YP66',
#   'A0A494C126'],
#  'ENSG00000148450': ['Q9Y3D2', 'H0YE51'],
#  'ENSG00000234616': ['O75564', 'A0A087WZD9'],
#  'ENSG00000165584': ['Q99909', 'A0A087WWQ6'],
#  'ENSG00000164007': ['Q8N6F1'],
#  'ENSG00000142227': ['P54852',
#   'M0QXN1',
#   'M0QXS0',
#   'M0QZ66',
#   'M0R122',
#   'M0R1L9'],
#  'ENSG00000048540': ['Q8TAP4',
#   'C9JE61',
#   'F5GYZ6',
#   'F5GZR3',
#   'F5H2N9',
#   'F5H3S4',
#   'F5H4K9',
#   'F5H4T0',
#   'F5H655',
#   'F6TDU8',
#   'Q05D86'],
#  'ENSG00000131507': ['Q9BT67'],
#  'ENSG00000277224': ['P62807'],
#  'ENSG00000178809': ['Q86UV7', 'C9JQH3', 'I3L0H3', 'J3KQW6'],
#  'ENSG00000132622': ['Q96MM6', 'Q5JX83'],
#  'ENSG00000085741': ['O96014'],
#  'ENSG00000160685': ['O15156'],
#  'ENSG00000100314': ['Q86V35'],
#  'ENSG00000106366': ['P05121'],
#  'ENSG00000160193': ['P57081'],
#  'ENSG00000168878': ['P07988', 'H0Y7V6', 'U3KQT2'],
#  'ENSG00000138495': ['Q14061', 'C9J8T6', 'H7C4E5', 'H7C5P5'],
#  'ENSG00000163545': ['Q9H093'],
#  'ENSG00000244754': ['Q92802',
#   'A0A6I8PL40',
#   'A0A6I8PL95',
#   'A0A6I8PRE0',
#   'A0A6I8PRI0',
#   'A0A6I8PRM1',
#   'A0A6I8PRP6',
#   'A0A6I8PRR0',
#   'A0A6I8PRR5',
#   'A0A6I8PRT3',
#   'A0A6I8PRV3',
#   'A0A6I8PRX5',
#   'A0A6I8PRY6',
#   'A0A6I8PS46',
#   'A0A6I8PU16',
#   'B4DPY1',
#   'D6R968'],
#  'ENSG00000119616': ['Q9Y324',
#   'G3V1S4',
#   'G3V2M5',
#   'G3V3N8',
#   'G3V5D2',
#   'G3V5L8',
#   'G3V5S9'],
#  'ENSG00000172554': ['Q9NY99', 'F2Z2D2'],
#  'ENSG00000101265': ['P50749'],
#  'ENSG00000150048': ['Q8NC01', 'E7ESV9', 'E9PFB4', 'F5H038', 'F8WCT4'],
#  'ENSG00000172262': ['P52739',
#   'D6R9I2',
#   'D6RAT8',
#   'D6RBK1',
#   'D6RD61',
#   'D6RE06',
#   'D6RFI6',
#   'D6RJ09',
#   'D6RJH2',
#   'H0Y974'],
#  'ENSG00000204822': ['Q96EL3', 'B9A051'],
#  'ENSG00000196247': ['Q9UII5',
#   'A0A087WYK5',
#   'A0A0B4J2G0',
#   'A0A8C8KK49',
#   'C9JSF9'],
#  'ENSG00000139651': ['Q8NDX6'],
#  'ENSG00000126950': ['Q53FP2'],
#  'ENSG00000135452': ['Q12999',
#   'F8VNT7',
#   'F8VP43',
#   'F8VS78',
#   'F8VVF8',
#   'F8VW54',
#   'F8VWE0'],
#  'ENSG00000181610': ['Q9Y3D9', 'J3QLC1', 'J3QLR8'],
#  'ENSG00000184640': ['Q9UHD8',
#   'A0A6Q8PHC2',
#   'K7EIE4',
#   'K7EJ51',
#   'K7EJV0',
#   'K7EJZ2',
#   'K7EK18',
#   'K7EKN4',
#   'K7EL40',
#   'K7EMW8',
#   'K7EN52',
#   'K7ENL0',
#   'K7ENQ5',
#   'K7EPY1',
#   'K7EQ08',
#   'K7EQD7',
#   'K7ER14',
#   'K7ER34',
#   'K7ER52'],
#  'ENSG00000153044': ['Q9H3R5', 'B3KVZ3', 'H0Y9E6'],
#  'ENSG00000221823': ['P63098', 'D3YTA9', 'F6U1T9'],
#  'ENSG00000151615': ['Q12837'],
#  'ENSG00000108854': ['Q9HAU4', 'J3QLG1', 'J3QQM4', 'J3QRY2'],
#  'ENSG00000049883': ['Q8WV60',
#   'B7Z8R2',
#   'D6RGK0',
#   'D6RIZ0',
#   'D6RJH8',
#   'E5RHU2',
#   'F6S289'],
#  'ENSG00000163517': ['Q96DB2',
#   'B5MC52',
#   'B5MCQ6',
#   'B5MCS3',
#   'B5MCU6',
#   'B5MCV5',
#   'B5MD06',
#   'C9J528',
#   'C9JBI4',
#   'C9JEC8',
#   'C9JMH0',
#   'E7ETT9',
#   'F8WF94',
#   'Q658J9'],
#  'ENSG00000110330': ['Q13490',
#   'E9PI77',
#   'E9PIW1',
#   'E9PMH5',
#   'E9PNM6',
#   'E9PQZ9',
#   'H0YDY3'],
#  'ENSG00000257335': ['O43451', 'E7EW87', 'E9PEQ5'],
#  'ENSG00000150281': ['Q16619'],
#  'ENSG00000124226': ['Q9Y508',
#   'A0A096LNN8',
#   'A0A096LNT1',
#   'A0A096LNV3',
#   'A0A096LP02',
#   'A0A096LPF9'],
#  'ENSG00000085365': ['O15126',
#   'A0A087WTX8',
#   'A0A087WU14',
#   'A0A087WXB0',
#   'A0A087WZA6'],
#  'ENSG00000108439': ['Q9NVS9',
#   'A0A286YF16',
#   'A0A286YF38',
#   'A0A286YFA1',
#   'A0A286YFL3',
#   'J3QQV6',
#   'J3QQZ9'],
#  'ENSG00000124237': ['Q9H1P6'],
#  'ENSG00000107164': ['Q96I24', 'A0A494C1K6', 'A0A8V8TNQ2'],
#  'ENSG00000133226': ['Q8IYB3',
#   'A0A0S2Z4Z6',
#   'A0A994J4Y3',
#   'A0A994J7H1',
#   'A0A994J7V4',
#   'A9Z1X7',
#   'M0QXG5',
#   'M0R088',
#   'M0R1E7'],
#  'ENSG00000171962': ['Q9H069',
#   'J3KRB8',
#   'J3KRN8',
#   'J3QR90',
#   'J3QRC9',
#   'J3QRH8',
#   'J3QS14',
#   'J3QSG4',
#   'K7EJT6'],
#  'ENSG00000100246': ['O96015', 'B0QXZ5'],
#  'ENSG00000124107': ['P03973'],
#  'ENSG00000182093': ['O00258',
#   'A0A096LNK8',
#   'A0A096LNT6',
#   'A0A3B3ISA8',
#   'A0A3B3ISE5',
#   'A0A3B3IT79',
#   'A0A3B3IUG4',
#   'B4DLW3',
#   'B7Z1T1',
#   'C9JLV3',
#   'H7BYE5',
#   'H7C384'],
#  'ENSG00000100284': ['O60784',
#   'B0QY01',
#   'B0QY02',
#   'F8WAW7',
#   'F8WB30',
#   'F8WBB0',
#   'F8WE29',
#   'H7BYN7',
#   'V9GYF4',
#   'V9GZ68'],
#  'ENSG00000149300': ['Q96A22', 'E9PPX5'],
#  'ENSG00000123975': ['P33552'],
#  'ENSG00000174428': ['Q6EKJ0', 'A0A087WW90', 'A0A494C1N8'],
#  'ENSG00000101443': ['Q14508', 'A8K2M3'],
#  'ENSG00000128383': ['P31941'],
#  'ENSG00000188629': ['Q13360', 'K7EK36', 'K7EQU1'],
#  'ENSG00000167720': ['Q9GZT4',
#   'I3L3N0',
#   'I3L4B4',
#   'I3L4L3',
#   'I3L4W4',
#   'Q3ZK31',
#   'V9GYE8'],
#  'ENSG00000103876': ['P16930',
#   'A0A804HJ13',
#   'A0A804HJX2',
#   'B7Z4W2',
#   'H0YLC7',
#   'H3BNP8'],
#  'ENSG00000119865': ['Q96F85', 'B8ZZB8'],
#  'ENSG00000164631': ['P17014', 'H9KV98'],
#  'ENSG00000099721': ['Q99218'],
#  'ENSG00000131914': ['Q9H9Z2'],
#  'ENSG00000131096': ['P10082'],
#  'ENSG00000157500': ['Q9UKG1', 'C9JAB0', 'C9K0C4'],
#  'ENSG00000007216': ['Q13183', 'J3QL78', 'J3QR70'],
#  'ENSG00000155265': ['Q2TAP0'],
#  'ENSG00000171161': ['Q499Z4', 'D6RD56', 'D6RH11'],
#  'ENSG00000168288': ['Q9H3L0', 'F8WEC0'],
#  'ENSG00000167941': ['Q9BQB4'],
#  'ENSG00000141570': ['Q9HC52', 'C9J6K3', 'C9JM54'],
#  'ENSG00000183617': ['Q6P161', 'K7ENN2'],
#  'ENSG00000158815': ['O60258'],
#  'ENSG00000075426': ['P15408', 'C9JCN8'],
#  'ENSG00000187699': ['Q9BSF0', 'C9JS57', 'H7BZ15'],
#  'ENSG00000168958': ['Q9GZY8',
#   'A0A0A0MS29',
#   'A0A9H3ZVE5',
#   'A0A9L9PXN3',
#   'A0A9L9PY92',
#   'A0A9L9PYL0',
#   'C9J846',
#   'C9JAF1',
#   'C9JHF5',
#   'C9JI76',
#   'C9JU19',
#   'E9PK16',
#   'E9PKS0',
#   'E9PPR7',
#   'E9PPW6',
#   'E9PQX8',
#   'H7C433'],
#  'ENSG00000138085': ['Q6UW56', 'C9JA62'],
#  'ENSG00000145715': ['P20936', 'E9PGC0'],
#  'ENSG00000254505': ['Q9BY43', 'E9PQ80', 'E9PQI5', 'H0YI89', 'H0YIN6'],
#  'ENSG00000182580': ['P54753'],
#  'ENSG00000275302': ['P13236', 'Q7M4M2'],
#  ...}
