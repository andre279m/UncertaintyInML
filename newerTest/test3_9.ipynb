# %% [markdown]
# # Imports

# %%
# %pip install -r requirements3_12.txt
# Out:
# Requirement already satisfied: numpy in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from -r requirements3_12.txt (line 1)) (1.26.2)
# Requirement already satisfied: scipy in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from -r requirements3_12.txt (line 2)) (1.11.4)
# Requirement already satisfied: rdflib in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from -r requirements3_12.txt (line 3)) (7.0.0)
# Requirement already satisfied: seaborn in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from -r requirements3_12.txt (line 4)) (0.13.0)
# Requirement already satisfied: scikit-learn in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from -r requirements3_12.txt (line 5)) (1.3.2)
# Requirement already satisfied: sparqlwrapper in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from -r requirements3_12.txt (line 6)) (2.0.0)
# Requirement already satisfied: gensim in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from -r requirements3_12.txt (line 7)) (4.3.2)
# Requirement already satisfied: tqdm in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from -r requirements3_12.txt (line 8)) (4.66.1)
# Requirement already satisfied: matplotlib in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from -r requirements3_12.txt (line 9)) (3.8.2)
# Requirement already satisfied: aiohttp in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from -r requirements3_12.txt (line 10)) (3.9.1)
# Requirement already satisfied: networkx in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from -r requirements3_12.txt (line 11)) (2.8.8)
# Requirement already satisfied: torch==1.13.1 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from -r requirements3_12.txt (line 12)) (1.13.1)
# Requirement already satisfied: pyrdf2vec==0.2.3 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from -r requirements3_12.txt (line 13)) (0.2.3)
# Requirement already satisfied: typing-extensions in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from torch==1.13.1->-r requirements3_12.txt (line 12)) (4.9.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from torch==1.13.1->-r requirements3_12.txt (line 12)) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from torch==1.13.1->-r requirements3_12.txt (line 12)) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from torch==1.13.1->-r requirements3_12.txt (line 12)) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from torch==1.13.1->-r requirements3_12.txt (line 12)) (11.7.99)
# Requirement already satisfied: attrs<22.0.0,>=21.2.0 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from pyrdf2vec==0.2.3->-r requirements3_12.txt (line 13)) (21.4.0)
# Requirement already satisfied: cachetools<5.0.0,>=4.2.2 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from pyrdf2vec==0.2.3->-r requirements3_12.txt (line 13)) (4.2.4)
# Requirement already satisfied: python-Levenshtein<0.13.0,>=0.12.2 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from pyrdf2vec==0.2.3->-r requirements3_12.txt (line 13)) (0.12.2)
# Requirement already satisfied: python-louvain<0.16,>=0.15 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from pyrdf2vec==0.2.3->-r requirements3_12.txt (line 13)) (0.15)
# Requirement already satisfied: tomlkit<0.8.0,>=0.7.2 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from pyrdf2vec==0.2.3->-r requirements3_12.txt (line 13)) (0.7.2)
# Requirement already satisfied: setuptools in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->-r requirements3_12.txt (line 12)) (68.0.0)
# Requirement already satisfied: wheel in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->-r requirements3_12.txt (line 12)) (0.41.2)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from rdflib->-r requirements3_12.txt (line 3)) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from rdflib->-r requirements3_12.txt (line 3)) (3.1.1)
# Requirement already satisfied: pandas>=1.2 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from seaborn->-r requirements3_12.txt (line 4)) (2.1.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from scikit-learn->-r requirements3_12.txt (line 5)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from scikit-learn->-r requirements3_12.txt (line 5)) (3.2.0)
# Requirement already satisfied: smart-open>=1.8.1 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from gensim->-r requirements3_12.txt (line 7)) (6.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from matplotlib->-r requirements3_12.txt (line 9)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from matplotlib->-r requirements3_12.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from matplotlib->-r requirements3_12.txt (line 9)) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from matplotlib->-r requirements3_12.txt (line 9)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from matplotlib->-r requirements3_12.txt (line 9)) (23.2)
# Requirement already satisfied: pillow>=8 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from matplotlib->-r requirements3_12.txt (line 9)) (10.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from matplotlib->-r requirements3_12.txt (line 9)) (2.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from aiohttp->-r requirements3_12.txt (line 10)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from aiohttp->-r requirements3_12.txt (line 10)) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from aiohttp->-r requirements3_12.txt (line 10)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from aiohttp->-r requirements3_12.txt (line 10)) (1.3.1)
# Requirement already satisfied: six in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib->-r requirements3_12.txt (line 3)) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from pandas>=1.2->seaborn->-r requirements3_12.txt (line 4)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from pandas>=1.2->seaborn->-r requirements3_12.txt (line 4)) (2023.3)
# Requirement already satisfied: idna>=2.0 in /home/andre279m/anaconda3/envs/latest/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp->-r requirements3_12.txt (line 10)) (3.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import rdflib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from pyrdf2vec.graphs import kg
from pyrdf2vec.rdf2vec import RDF2VecTransformer
from pyrdf2vec.graphs import Vertex
from pyrdf2vec.embedders import Word2Vec
from pyrdf2vec.samplers import UniformSampler, ObjFreqSampler, PredFreqSampler
from pyrdf2vec.walkers import RandomWalker, WLWalker, WalkletWalker
import random

# %% [markdown]
# # Files

# %%
gene_ontology_file_path = '../DB/go.owl'
protein_file_path = '../DB/9606.protein.enrichment.terms.v12.0.txt'
protein_links_file_path = '../DB/9606.protein.links.v12.0.txt'
protein_full_links_file_path = '../DB/9606.protein.links.detailed.v12.0.txt'

# %% [markdown]
# # Creating the Knowledge graph

# %%
g = rdflib.Graph()
g.parse(gene_ontology_file_path, format = 'xml');

# %%
prots = []

with open(protein_file_path , 'r') as prot_annot:
    prot_annot.readline()
    for line in prot_annot:
        elements_annot = line.split('\t')
        id_prot, GO_term = elements_annot[0], elements_annot[2]
        if GO_term.startswith('GO:') :
            url_GO_term = 'http://purl.obolibrary.org/obo/GO_' + GO_term.split(':')[1]
            url_prot = 'https://string-db.org/network/' + id_prot
            if id_prot not in prots:
                prots.append(id_prot)
            #if (id_prot in data2["protein1"].values or id_prot in data2["protein2"].values) and url_prot not in prots:
            #    prots.append(url_prot)
            g.add((rdflib.term.URIRef(url_prot), rdflib.term.URIRef('http://purl.obolibrary.org/obo/go.owl#has_function') , rdflib.term.URIRef(url_GO_term)))

# %% [markdown]
# # Distribution of Confidence

# %%
data_full = pd.read_csv(protein_full_links_file_path, sep=" ", header=0)
data_full = data_full[data_full["protein1"].isin(prots) & data_full["protein2"].isin(prots)]
data_full
# Out:
#                       protein1              protein2  neighborhood  fusion  \
# 0         9606.ENSP00000000233  9606.ENSP00000356607             0       0
# 1         9606.ENSP00000000233  9606.ENSP00000427567             0       0
# 2         9606.ENSP00000000233  9606.ENSP00000253413             0       0
# 3         9606.ENSP00000000233  9606.ENSP00000493357             0       0
# 4         9606.ENSP00000000233  9606.ENSP00000324127             0       0
# ...                        ...                   ...           ...     ...
# 13715398  9606.ENSP00000501317  9606.ENSP00000360858             0       0
# 13715399  9606.ENSP00000501317  9606.ENSP00000475489             0       0
# 13715400  9606.ENSP00000501317  9606.ENSP00000370447             0       0
# 13715401  9606.ENSP00000501317  9606.ENSP00000312272             0       0
# 13715403  9606.ENSP00000501317  9606.ENSP00000404074             0       0
#
#           cooccurence  coexpression  experimental  database  textmining  \
# 0                   0            45           134         0          81
# 1                   0             0           128         0          70
# 2                   0           118            49         0          69
# 3                   0            56            53         0         457
# 4                   0             0            46         0         197
# ...               ...           ...           ...       ...         ...
# 13715398            0             0             0         0         328
# 13715399            0            60            99         0         126
# 13715400            0            55           111         0          79
# 13715401            0             0             0         0         227
# 13715403            0            49            63         0         227
#
#           combined_score
# 0                    173
# 1                    154
# 2                    151
# 3                    471
# 4                    201
# ...                  ...
# 13715398             327
# 13715399             195
# 13715400             158
# 13715401             226
# 13715403             251
#
# [13337088 rows x 10 columns]

# %%
# Create a histogram and get the patches
counts, bins, patches = plt.hist(data_full['combined_score'], bins=10, bottom=list(range(0,1000,100)), range=(0,1000))

# Set the title and labels
plt.title('Number of entries in STRING DB')
plt.xlabel('Confidence Score')
plt.ylabel('Number of interactions')

# Annotate histogram with the number of data points in each bin
for count, bin, patch in zip(counts, bins, patches):
    height = patch.get_height()
    plt.text(bin, height, str(int(count)), va='bottom')

plt.show()

# %%
fig, axs = plt.subplots(2, 4)
axs[0, 0].hist(data_full['combined_score'],bins=10,bottom=list(range(0,1000,100)),range=(0,1000));
axs[0, 0].set_title('Combined score', y=1.1)  # Increase the y parameter to move the title up
axs[0, 1].hist(data_full['neighborhood'],bins=10,bottom=list(range(0,1000,100)),range=(0,1000));
axs[0, 1].set_title('Conserved Neighbourhood', y=1.1)
axs[0, 2].hist(data_full['fusion'],bins=10,bottom=list(range(0,1000,100)),range=(0,1000));
axs[0, 2].set_title('Fusion', y=1.1)
axs[0, 3].hist(data_full['cooccurence'],bins=10,bottom=list(range(0,1000,100)),range=(0,1000));
axs[0, 3].set_title('Co-occurrence', y=1.1)
axs[1, 0].hist(data_full['experimental'],bins=10,bottom=list(range(0,1000,100)),range=(0,1000));
axs[1, 0].set_title('Experimental', y=1.1)
axs[1, 1].hist(data_full['database'],bins=10,bottom=list(range(0,1000,100)),range=(0,1000));
axs[1, 1].set_title('Database', y=1.1)
axs[1, 2].hist(data_full['coexpression'],bins=10,bottom=list(range(0,1000,100)),range=(0,1000));
axs[1, 2].set_title('Co-expression', y=1.1)
axs[1, 3].hist(data_full['textmining'],bins=10,bottom=list(range(0,1000,100)),range=(0,1000));
axs[1, 3].set_title('Text mining', y=1.1);

plt.subplots_adjust(left=0.01, right=1.3, hspace=0.5)

# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
#    ax.label_outer()

# %% [markdown]
# # Creating thresholds

# %%
# Thresholds for the whole dataset

# data8 = data_full.where(data_full['combined_score']>800).copy().dropna().reset_index(drop=True)
# data6 = data_full.where(data_full['combined_score']>600).copy().dropna().reset_index(drop=True)
# data4 = data_full.where(data_full['combined_score']>400).copy().dropna().reset_index(drop=True)
# data2 = data_full.where(data_full['combined_score']>200).copy().dropna().reset_index(drop=True)
# dataSample = data_full

# Thresholds for fixed size sampling (1000 samples)

data8 = data_full.where(data_full['combined_score']>800).copy().dropna().reset_index(drop=True).sample(n=1000, random_state=42)
data6 = data_full.where(data_full['combined_score']>600).copy().dropna().reset_index(drop=True).sample(n=1000,random_state=42)
data4 = data_full.where(data_full['combined_score']>400).copy().dropna().reset_index(drop=True).sample(n=1000,random_state=42)
data2 = data_full.where(data_full['combined_score']>200).copy().dropna().reset_index(drop=True).sample(n=1000,random_state=42)
dataSample = data_full.sample(n=1000,random_state=42)

# Thresholds for fraction sampling (10% of the data)

# data8 = data_full.where(data_full['combined_score']>800).copy().dropna().reset_index(drop=True).sample(frac=0.1, random_state=42)
# data6 = data_full.where(data_full['combined_score']>600).copy().dropna().reset_index(drop=True).sample(frac=0.1,random_state=42)
# data4 = data_full.where(data_full['combined_score']>400).copy().dropna().reset_index(drop=True).sample(frac=0.1,random_state=42)
# data2 = data_full.where(data_full['combined_score']>200).copy().dropna().reset_index(drop=True).sample(frac=0.1,random_state=42)
# dataSample = data_full.sample(frac=0.1,random_state=42)


# Thresholds for uniform sampling

# select = []
# for N in range(1000):
#    ind = int(N*len(data8)/1000)
#    select.append(ind)
# data8 = data8.loc[select]
#select = []
#for N in range(1000):
#    ind = int(N*len(data6)/1000)
#    select.append(ind)
#data6 = data6.loc[select]
#select = []
#for N in range(1000):
#    ind = int(N*len(data4)/1000)
#    select.append(ind)
#data4 = data4.loc[select]
#select = []
#for N in range(1000):
#    ind = int(N*len(data8)/1000)
#    select.append(ind)
#data2 = data2.loc[select]
#select = []
#for N in range(1000):
#    ind = int(N*len(dataSample)/1000)
#    select.append(ind)
#dataSample = dataSample.reset_index(drop=True).loc[select]

# %% [markdown]
# # Pipeline

# %%
# Defining rdf2vec paramenters
vector_size = 200
n_walks = 100
type_word2vec = 'skip-gram'
walk_depth = 4
walker_type = 'wl'
sampler_type = 'uniform'

# Creating a pyrdf2vec graph
g_pyrdf2vec = kg.KG(mul_req=False)
for (s, p, o) in g:
    s_v = Vertex(str(s))
    o_v = Vertex(str(o))
    p_v = Vertex(str(p), predicate=True, vprev=s_v, vnext=o_v)
    g_pyrdf2vec.add_vertex(s_v)
    g_pyrdf2vec.add_vertex(p_v)
    g_pyrdf2vec.add_vertex(o_v)
    g_pyrdf2vec.add_edge(s_v, p_v)
    g_pyrdf2vec.add_edge(p_v, o_v)

# Defining the word2vec strategy
if type_word2vec == 'CBOW':
    sg_value = 0
elif type_word2vec == 'skip-gram':
    sg_value = 1

# Defining sampling strategy 
if sampler_type.lower() == 'uniform':
    sampler = UniformSampler()
elif sampler_type.lower() == 'predfreq':
    sampler = PredFreqSampler()
elif sampler_type.lower() == 'objfreq':
    sampler = ObjFreqSampler()

# Defining warker strategy
if walker_type.lower() == 'random':
    walker = RandomWalker(max_depth=walk_depth, max_walks=n_walks, sampler = sampler)
elif walker_type.lower() == 'wl':
    walker = WLWalker(max_depth=walk_depth, max_walks=n_walks, sampler = sampler)
elif walker_type.lower() == 'walklet':
    walker = WalkletWalker(max_depth=walk_depth, max_walks=n_walks, sampler = sampler)

# Training RDF2Vec embeddings    
transformer = RDF2VecTransformer(Word2Vec(vector_size=vector_size, sg=sg_value), walkers=[walker])

# %%
random.seed(42)

f1_results = {} # list of f1 results

for i in range(800, -1, -200):
    if i == 800:
        data = data8
    elif i == 600:
        data = data6
    elif i == 400:
        data = data4
    elif i == 200:
        data = data2
    elif i == 0:
        data = dataSample

    # Creating a list of all proteins
    prots = []

    for value in data["protein1"].values:
        url_prot = 'https://string-db.org/network/' + value
        if url_prot not in prots:
            prots.append(url_prot)

    for value in data["protein2"].values:
        url_prot = 'https://string-db.org/network/' + value
        if url_prot not in prots:
            prots.append(url_prot)

    #Generating the embeddings
    embeddings = transformer.fit_transform(g_pyrdf2vec, prots)
    # Saving embedding in a dictionary
    dict_embeddings = {prots[i]: embeddings[i] for i in range(len(prots))}
    print('Embeddings generated')

    pairs_prots = []
    for d in data.values:
        pairs_prots.append(('https://string-db.org/network/' + d[0],'https://string-db.org/network/' + d[1], 1))

    pairs_prots = set(pairs_prots)

    negative_pairs_prots = []
    for prot in prots:
        for prot2 in prots:
            if (prot,prot2,1) in pairs_prots:
                continue
            elif prot != prot2:
                negative_pairs_prots.append((prot,prot2,0))

    negative_pairs_prots = random.sample(negative_pairs_prots, len(pairs_prots))

    # Generating pair representations using haddamard operator # other possibilities are concatenation, wl-1 or wl-2
    X, y = [], []
    for prot1, prot2, label in pairs_prots:
        emb_prot1 = dict_embeddings[prot1].reshape(1, vector_size)
        emb_prot2 = dict_embeddings[prot2].reshape(1, vector_size)
        hada = np.multiply(emb_prot1, emb_prot2)
        X.append(hada.tolist()[0])
        y.append(int(label))

    for prot1, prot2, label in negative_pairs_prots:
        emb_prot1 = dict_embeddings[prot1].reshape(1, vector_size)
        emb_prot2 = dict_embeddings[prot2].reshape(1, vector_size)
        hada = np.multiply(emb_prot1, emb_prot2)
        X.append(hada.tolist()[0])
        y.append(int(label))

    f1 = []

    # Creating training set and test set
    sss = StratifiedShuffleSplit(n_splits=10, random_state=42)
    X, y = np.array(X), np.array(y)
    for train_index, test_index in sss.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
    #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=True)

        # Training Random Forest classifier
        rf_model = RandomForestClassifier()
        rf_model.fit(X_train, y_train)

        # Obtaining predictions
        pred_test = rf_model.predict(X_test)

        # Computing performance metrics
        weighted_avg_f1 = metrics.f1_score(y_test, pred_test, average='weighted')
        f1.append(weighted_avg_f1)
    
    f1_mean = np.mean(f1)
    f1_results[i] = f1_mean

    # Printing performance metrics
    print('Weighted Average F-measure for ' + str(i) + ' or more confidence score= ' + str(f1_mean))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 31
#      28         prots.append(url_prot)
#      30 #Generating the embeddings
# ---> 31 embeddings = transformer.fit_transform(g_pyrdf2vec, prots)
#      32 # Saving embedding in a dictionary
#      33 dict_embeddings = {prots[i]: embeddings[i] for i in range(len(prots))}
#
# File ~/anaconda3/envs/latest/lib/python3.11/site-packages/pyrdf2vec/rdf2vec.py:143, in RDF2VecTransformer.fit_transform(self, kg, entities, is_update)
#     126 """Creates a model and generates embeddings and literals for the
#     127 provided entities.
#     128
#    (...)
#     140
#     141 """
#     142 self._is_extract_walks_literals = True
# --> 143 self.fit(self.get_walks(kg, entities), is_update)
#     144 return self.transform(kg, entities)
#
# File ~/anaconda3/envs/latest/lib/python3.11/site-packages/pyrdf2vec/rdf2vec.py:178, in RDF2VecTransformer.get_walks(self, kg, entities)
#     176 tic = time.perf_counter()
#     177 for walker in self.walkers:
# --> 178     walks += walker.extract(kg, entities, self.verbose)
#     179 toc = time.perf_counter()
#     181 self._update(self._entities, entities)
#
# File ~/anaconda3/envs/latest/lib/python3.11/site-packages/pyrdf2vec/walkers/weisfeiler_lehman.py:152, in WLWalker.extract(self, kg, entities, verbose)
#     131 def extract(
#     132     self, kg: KG, entities: Entities, verbose: int = 0
#     133 ) -> List[List[SWalk]]:
#     134     """Fits the provided sampling strategy and then calls the
#     135     private _extract method that is implemented for each of the
#     136     walking strategies.
#    (...)
#     150
#     151     """
# --> 152     self._weisfeiler_lehman(kg)
#     153     return super().extract(kg, entities, verbose)
#
# File ~/anaconda3/envs/latest/lib/python3.11/site-packages/pyrdf2vec/walkers/weisfeiler_lehman.py:119, in WLWalker._weisfeiler_lehman(self, kg)
#     115 for vertex in kg._vertices:
#     116     if self.md5_bytes:
#     117         self._label_map[vertex][n] = str(
#     118             md5(
# --> 119                 self._create_label(kg, vertex, n).encode()
#     120             ).digest()[: self.md5_bytes]
#     121         )
#     122     else:
#     123         self._label_map[vertex][n] = str(
#     124             self._create_label(kg, vertex, n)
#     125         )
#
# File ~/anaconda3/envs/latest/lib/python3.11/site-packages/pyrdf2vec/walkers/weisfeiler_lehman.py:91, in WLWalker._create_label(self, kg, vertex, n)
#      83 if len(self._label_map) == 0:
#      84     self._weisfeiler_lehman(kg)
#      86 suffix = "-".join(
#      87     sorted(
#      88         set(
#      89             [
#      90                 self._label_map[neighbor][n - 1]
# ---> 91                 for neighbor in kg.get_neighbors(
#      92                     vertex, is_reverse=True
#      93                 )
#      94             ]
#      95         )
#      96     )
#      97 )
#      98 return f"{self._label_map[vertex][n - 1]}-{suffix}"
#
# File ~/anaconda3/envs/latest/lib/python3.11/site-packages/pyrdf2vec/graphs/kg.py:329, in KG.get_neighbors(self, vertex, is_reverse)
#     316 """Gets the children or parents neighbors of a vertex.
#     317
#     318 Args:
#    (...)
#     326
#     327 """
#     328 if is_reverse:
# --> 329     return self._inv_transition_matrix[vertex]
#     330 return self._transition_matrix[vertex]
#
# File ~/anaconda3/envs/latest/lib/python3.11/site-packages/pyrdf2vec/graphs/vertex.py:50, in Vertex.__hash__(self)
#      41 """Defines behavior for when hash() is called on a vertex.
#      42
#      43 Returns:
#    (...)
#      47
#      48 """
#      49 if self.predicate:
# ---> 50     return hash((self.vprev, self.vnext, self.name))
#      51 return hash(self.name)
#
# File ~/anaconda3/envs/latest/lib/python3.11/site-packages/pyrdf2vec/graphs/vertex.py:51, in Vertex.__hash__(self)
#      49 if self.predicate:
#      50     return hash((self.vprev, self.vnext, self.name))
# ---> 51 return hash(self.name)
#
# KeyboardInterrupt:

# %% [markdown]
# # F-measure Analysis

# %%
f1_x = list(f1_results.keys())
f1_y = list(f1_results.values())

plt.scatter(f1_x,f1_y)
plt.xlabel('Confidence')
plt.ylabel('F1-score')
plt.ylim(0,1)
plt.title('F1-score vs Confidence')

#use for loop to add annotations to each point in plot 
for i, txt in enumerate(f1_y):
    plt.annotate(round(txt,3), (f1_x[i]+.25, f1_y[i]), fontsize=12)

plt.show()
